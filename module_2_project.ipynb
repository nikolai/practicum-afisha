# %% [markdown]
# <div style="border:solid Green 2px; border-radius: 10px;  padding: 40px">
# <b>Привет, Николай!👋</b>
#
# Меня зовут Зуева Юлия, можно просто Юля 😏 Я буду ревьюером твоего проекта. Предлагаю обращаться на "ты", но если это неудобно, пожалуйста, скажи об этом!
#
# Моя основная цель - помочь тебе стать компетентным Data Scientist'ом: вместе преодолеть трудности и еще больше развить твои сильные навыки 💪 В твоей работе я оставила комментарии, которые должны в этом помочь. Для твоего удобства комментарии раскрашены разными цветами:
# <br/>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> В случае корректного решения (или отдельных его моментов). На такие решения можно опираться в будущем.
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Если есть возможность как-либо улучшить решение. Ты можешь учесть эти комментарии при доработке проекта, однако для зачета это не обязательно.
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b> Если решение требует внесения правок. Проект не может быть принят, если остались не отработанные комментарии данного типа.
# </div>
#
# Чтобы наша с тобой работа была еще эффективнее, ты точно так же можешь оставлять комментарии и задавать мне вопросы. Для таких случаев, пожалуйста, выбери собственное оформление комментариев, которое будет отличаться от моего, чтобы не создавалась путаница. По этой же причине попрошу тебя не удалять и не изменять мои комментарии. Все это позволит лучше ориентироваться в нашем с тобой диалоге, а повторную проверку (в случае ее необходимости) выполнять оперативнее 🚀
#
# Не спеши расстраиваться, если что-то не удалось с первого раза. Вместе мы обязательно разберемся со всеми трудностями! 🤓

# %% [markdown]
# ### 🎁 СНГ: Привет, Юля! Давай разбираться с этим вместе! Добавил свои комментарии с пометкой ФИО - "🎁 СНГ"

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# Автор: Смирнов Николай Георгиевич
#
# Дата: 24.01.2026
#
# ## Введение
#
# Команда маркетинга Яндекс Афиши хочет лучше понимать поведение пользователей, чтобы выявлять перспективных клиентов и оптимизировать маркетинговые бюджеты. Для этого необходимо провести исследовательский анализ данных и понять, какие пользователи с большей вероятностью возвращаются на платформу и делают заказы повторно.
#
# **Цель проекта:** выявить характеристики и признаки пользователей, которые с большей вероятностью возвращаются на платформу и совершают повторные заказы.
#
# **Задачи проекта:**
# 1. Выгрузить данные о покупках с помощью SQL-запроса из базы данных PostgreSQL
# 2. Провести предварительную обработку данных
# 3. Выполнить исследовательский анализ данных
# 4. Выявить ключевые признаки лояльных пользователей
# 5. Сформулировать выводы и рекомендации для маркетинговой команды

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Вводная часть <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здорово, что оставляешь вводную часть! Она помогает быстро понять цель, контекст и структуру работы, что будет удобно не только для тебя при возвращении к проекту спустя время, но и любому другому читателю (если, например, публикуешь в открытый доступ для портфолио). Воспринимаем эту тетрадку не просто как выполнение домашней работы на курсе, а как полноценный исследовательский проект.
#
# Как правило, во вводную часть включают название проекта, краткое описание цели, используемых данных (источники, объем, особенности), нюансы самого проекта (специфические условия, ограничения, предположения и т.д.). Иногда также сразу обозначают план шагов. Другими словами, вводная часть призвана отразить, что мы делаем, с чем работаем и на каких условиях.
# </div>

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %%
# Установка библиотек (если требуется)
# !pip -q install phik
# !pip -q install python-dotenv

# %%
# Импорт библиотек
# Стандартные библиотеки
import ast
import os

# Сторонние библиотеки
import numpy as np
import pandas as pd
import phik
import seaborn as sns
from dotenv import load_dotenv
from matplotlib import pyplot as plt
from sqlalchemy import create_engine

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Импорты <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Напомню, что перед отправкой проекта важно сбрасывать ядро (очищать память от созданных объектов) и заново запускать проект с самого начала, чтобы проверить на наличие ошибок в коде при последовательном исполнении ячеек. Сейчас этого сделано не было, нумерация ячеек начинается не с 1.
#
#
# * Чтобы при установке новой библиотеки не выводилась информация о процессе и зависимостях, можно добавлять опцию `--quiet` или просто `-q`.
#
#
# * Все необходимые библиотеки лучше подгружаешь сразу в начале проекта, это соответствует стандартам оформления кода <a href='https://pyplanet.ru/article/pep-0008.html'>PEP 8</a>. Такой подход позволяет сразу видеть, какое окружение необходимо для запуска проекта, избежать дублирования импортов в разных частях кода, а также облегчить отладку и переносимость проекта. Сейчас один импорт затерялся в коде.
#
#
# * Хорошей практикой также является упорядочивание импортов. PEP 8 рекомендует сначала подгружать стандартные python-библиотеки, затем сторонние. Но для удобства каждую их этих групп также можно структурировать по тематике. Например, библиотеки для работы с данными, для работы с графиками и т.д. Тогда будет удобнее поддерживать порядок в импортах от проекта к проекту, не подгружать лишнее.
#
#
# </div>

# %%
# Загрузить переменные из .env файла
load_dotenv()
# Out:
# True

# %%
db_config = {
    'user': os.getenv('DB_USER'), # имя пользователя
    'pwd':  os.getenv('DB_PASSWORD'), # пароль
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT'), # порт подключения
    'db': os.getenv('DB_NAME') # название базы данных
}
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)
engine = create_engine(connection_string)

# %%
query = """
SELECT
  user_id,
  device_type_canonical,
  order_id,
  created_dt_msk as order_dt,
  created_ts_msk as order_ts,
  currency_code,
  revenue,
  tickets_count,
  extract(day from created_dt_msk - LAG(created_dt_msk) over (partition by user_id order by created_dt_msk)) as days_since_prev,
  event_id,
  event_name_code as event_name,
  event_type_main,
  service_name,
  region_name,
  city_name
from
  afisha.purchases p
left join
  afisha.events e
using
  (event_id)
left join
  afisha.city c
using
  (city_id)
left join
  afisha.regions r
using
  (region_id)
where
  device_type_canonical in ('mobile', 'desktop')
  and event_type_main != 'фильм'
order by
    user_id
"""
local_dataset = 'afisha_local.csv'

load_dotenv()
print(os.getenv('USE_LOCAL_DATASET'))

if os.path.exists(local_dataset) and ast.literal_eval(os.getenv('USE_LOCAL_DATASET')):
  df = pd.read_csv(local_dataset)
  print(f'Dataset has been loaded from local file {local_dataset}')
  # корректируем типы данных с датами, так как при сохранении в csv они преобразуются в object:
  df['order_dt'] = pd.to_datetime(df['order_dt'])
  df['order_ts'] = pd.to_datetime(df['order_ts'])
else:
  df = pd.read_sql_query(query, con=engine)
  # сохраним датасет локально, чтобы не загружать из файла при рестарте ноутбука
  df.to_csv(local_dataset, index=False)
  print(f'Dataset has been loaded from sql database and saved to local file {local_dataset}')
df.sample(5)
# Out:
# False
# Dataset has been loaded from sql database and saved to local file afisha_local.csv
#                 user_id device_type_canonical  order_id   order_dt  \
# 189291  9d0808e41b1be28                mobile   8461215 2024-07-13
# 53304   1f80c7cb21b5c46               desktop   4774387 2024-10-14
# 109677  4f6302c4412be9e                mobile   1945669 2024-09-03
# 266675  e7c3f16ca26b719                mobile   1903938 2024-10-27
# 125711  60563f062db79c0                mobile   4897405 2024-08-18
#
#                   order_ts currency_code  revenue  tickets_count  \
# 189291 2024-07-13 15:39:58           rub    72.89              4
# 53304  2024-10-14 21:15:50           rub  1351.34              4
# 109677 2024-09-03 11:13:03           rub   171.78              5
# 266675 2024-10-27 11:58:33           rub   310.59              3
# 125711 2024-08-18 15:50:05           rub   782.48              2
#
#         days_since_prev  event_id                            event_name  \
# ...

# %% [markdown]
# Данные успешно загружены. На приведенном примере проблем не обнаружилось. Ключевые колонки имеют корректные значения. Условия фильтрации данных в SQL-запросе продиктованы бизнес-требованиями: оцениваем только мобильные и десктопные девайсы и не оцениваем фильмы, так как эти категории малочисленны.

# %%
print(f"Загружено строк: {len(df)}")
print(f"Период данных: {df['order_dt'].min()} - {df['order_dt'].max()}")
assert len(df) > 0, "Датасет пустой!"
# Out:
# Загружено строк: 290611
# Период данных: 2024-06-01 00:00:00 - 2024-10-31 00:00:00

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Загрузка данных <a class="tocSkip"></h4>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * Выгрузка данных проведена корректно! Была выполнена необходимая фильтрация данных, выгружены только необходимые для анализа данные. Отлично, что сразу подсчитываешь время между заказами для каждого пользователя.
#
#
# * Здорово, что засекречиваешь подключение! Лучше сразу в процессе работы держать чувствительные значения отдельно от основного содержания, иначе есть высокий риск забыть об этом нюансе.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> По этой же причине нужно убрать ключи и из описания задания.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Сейчас у тебя не совсем корректно заданы отступы в условии, из-за чего синтаксикс подсвечивается красным. В Python, в отличие от SQL, с отступами гораздо строже. Стантартным отступом считается 4 пробела.
#
# </div>

# %% [markdown]
# ### 🎁 СНГ: исправлено - удалил ключи из описания и из истории репозитория в github

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  str
#  1   device_type_canonical  290611 non-null  str
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[us]
#  4   order_ts               290611 non-null  datetime64[us]
#  5   currency_code          290611 non-null  str
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  str
#  11  event_type_main        290611 non-null  str
#  12  service_name           290611 non-null  str
#  13  region_name            290611 non-null  str
# ...

# %% [markdown]
# Пропуски имеются только в столбце `days_since_prev`. Это ожидаемо. Доля пропусков небольшая. Это нормально для этого поля.

# %% [markdown]
# Проверим максимальные значения в колонках для возможности корректировки типов данных:

# %%
df.describe()
# Out:
#            order_id                    order_dt                    order_ts  \
# count  2.906110e+05                      290611                      290611
# mean   4.326225e+06  2024-09-01 22:36:38.741272  2024-09-02 13:31:19.397731
# min    1.000000e+00         2024-06-01 00:00:00         2024-06-01 00:00:42
# 25%    2.163618e+06         2024-07-30 00:00:00  2024-07-30 11:53:37.500000
# 50%    4.326366e+06         2024-09-12 00:00:00         2024-09-12 14:02:10
# 75%    6.488330e+06         2024-10-09 00:00:00  2024-10-09 15:57:55.500000
# max    8.653108e+06         2024-10-31 00:00:00         2024-10-31 23:59:54
# std    2.497551e+06                         NaN                         NaN
#
#              revenue  tickets_count  days_since_prev       event_id
# count  290611.000000  290611.000000    268678.000000  290611.000000
# mean      625.584360       2.754311         3.222381  438019.834992
# min       -90.760000       1.000000         0.000000    4436.000000
# ...

# %% [markdown]
# Максимальные значения в колонках:
# - event_id: 437747 (достаточно uint32)
# - order_id: 8653108 (достаточно uint32)
# - tickets_count: 57 (достаточно uint32)

# %% [markdown]
# #### Вывод по разделу 1 (загрузка данных)
# Датафрейм имеет 15 колонок и 290611 строк. Период данных 2024-06-01 00:00:00 - 2024-10-31 00:00:00.
# Датасет занимает в оперативной памяти 33 МБ.
# Выгрузка прошла успешно. Некоторые типы колонок можно скорректировать.
#
# Статус модификации типов данных колонок:
# - `user_id` — object/строка, корректный тип
# - `device_type_canonical` — object/строка, можно скорректировать до category
# - `order_id` — int64, можно понизить до `uint32`
# - `order_dt` — datetime64[ns], корректный тип
# - `order_ts` — datetime64[ns], корректный тип
# - `currency_code` — object/строка, можно скорректировать до `category`
# - `revenue` — float64, можно понизить до `float32`
# - `tickets_count` — int64, можно понизить до `uint8`
# - `days_since_prev` — float64, так как содержит пропуски, можно понизить до `float32` (float16 переполняется при поиске среднего значения)
# - `event_id` — int64, можно понизить до `uint32`
# - `event_name` — object/строка, корректный тип
# - `event_type_main` — object/строка, можно скорректировать до `category`
# - `service_name` — object/строка, корректный тип
# - `region_name` — object/строка, корректный тип
# - `city_name` — object/строка, корректный тип
#
# Сделаем корректировку типов данных колонок в следующем разделе.

# %%
# Создадим копию датафрейма для сравнения после изменения типов данных
df_original = df.copy()
df_original_size_mb = df_original.memory_usage(deep=False).sum()/1024/1024
print(f'Размер датафрейма до изменения типов данных: {df_original_size_mb:.2f} МБ')
# Out:
# Размер датафрейма до изменения типов данных: 33.26 МБ

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Проверка корректности загруженных данных <a class="tocSkip"></h4>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * Хорошо, что убеждаешь в корректности данных! Если при подгрузке возникли проблемы, а мы их не обнаружим, все последующие расчеты могут быть искажены.
#
#
# * Круто, что не забываешь зафиксировать промежуточные наблюдения в выводах! Если потребуется вернуться к проекту спустя время, будет проще освежить в памяти все ключевые этапы работы, что и почему мы делали, что получили.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Стоит предположить, что пропуски, скорее всего, образовались на первых заказах пользователей, в таком случае у них не существует предыдущего, от которого можно было бы посчитать количество дней.
#
#
# * По результатам проверки корректности загруженных данных мы планируем дальнейшие шаги по обработке. Здесь можно было бы отметить, что нам потребуется привести выручку к единой валюте, убедиться, что пропуски действительно имеются только у первых заказов, выполнить проверку на дубликаты (полные и неполные), проверить категориальные столбцы на предмет неявных дубликатов (разный регистр, разный формат записи, опечатки) и все числовые столбцы на наличие невалидных значений и аномалий, опционально сменить типы данных на более оптимальные, чтобы уменьшить объем занимаемой памяти.
#
# </div>

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# #### **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %%
df_tenge_course = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %%
df_tenge_course.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    str
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 11.3 KB

# %% [markdown]
# Дата хранится в формате `object`, необходимо преобразовать в `datetime`.

# %%
df_tenge_course['data'] = pd.to_datetime(df_tenge_course['data'])
df_tenge_course.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    datetime64[us]
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    str
# dtypes: datetime64[us](1), float64(1), int64(1), str(1)
# memory usage: 11.3 KB

# %%
df_tenge_course.sample(5)
# Out:
#           data  nominal     curs  cdx
# 67  2024-03-17      100  20.4537  kzt
# 307 2024-11-12      100  19.9213  kzt
# 154 2024-06-12      100  19.8655  kzt
# 25  2024-02-04      100  20.1634  kzt
# 167 2024-06-25      100  18.8012  kzt

# %%
# проверим, как работает получение курса тенге по дате:
df_tenge_course.loc[df_tenge_course['data'] == '2024-03-26']['curs']/100
# Out:
# 76    0.205589
# Name: curs, dtype: float64

# %%
def convert_tenge_to_rub(row):
    if row['currency_code'] == 'kzt':
        tenge_to_rub_course = df_tenge_course.loc[df_tenge_course['data'] == row['order_dt']]['curs']/100
        return round((row['revenue'] * tenge_to_rub_course).iloc[0], 2)
    else:
        return row['revenue']

df['revenue_rub'] = df.apply(convert_tenge_to_rub, axis=1)

# %%
df[df['currency_code'] != 'kzt'].sample(3)
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 52282   1f5005b3af584c9               desktop   4312678 2024-08-08
# 22483   0beb8fc0c0a9ce1                mobile   4259724 2024-10-11
# 195149  a2cfc926084e15b                mobile   5940361 2024-09-30
#
#                   order_ts currency_code  revenue  tickets_count  \
# 52282  2024-08-08 17:52:48           rub   788.90              2
# 22483  2024-10-11 14:55:24           rub   525.99              2
# 195149 2024-09-30 13:24:53           rub  1541.75              3
#
#         days_since_prev  event_id                            event_name  \
# 52282               0.0    317299  a00e1032-6463-4fdc-a105-fdbb6789b556
# 22483               0.0    156687  5bfa16d5-9cf4-4107-944f-64495efae9ad
# 195149              0.0    244892  47390c87-b568-4780-9813-2498f6c399ca
#
#        event_type_main   service_name           region_name   city_name  \
# ...

# %%
df[df['currency_code'] == 'kzt'].sample(3)
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 7267    043f669c9f734b1               desktop   3911260 2024-06-11
# 186732  9934394758127f5                mobile   2643003 2024-10-10
# 142121  74dea54d0e7fadc                mobile   3680594 2024-06-05
#
#                   order_ts currency_code   revenue  tickets_count  \
# 7267   2024-06-11 15:19:24           kzt  13212.93              3
# 186732 2024-10-10 15:12:13           kzt    586.57              4
# 142121 2024-06-05 11:02:25           kzt   5548.24              3
#
#         days_since_prev  event_id                            event_name  \
# 7267                0.0    536826  76af4f88-c554-4e9e-9df4-1cc8aeec8959
# 186732             28.0    560731  d76e86d7-4d41-46e5-9cd6-61d7e1459a85
# 142121              0.0    533803  0686ac7b-6f3e-4177-bb73-16b54acd1223
#
#        event_type_main        service_name          region_name   city_name  \
# ...

# %% [markdown]
# Преобразование revenue в revenue_rub произведено корректно.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Перевод выручки в рубли <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С шагом справились, результат корректный!
# </div>
#
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Сперва следовало убедиться в корректности данных с курсом, по всем ли датам есть курс, адекватные ли там значения, нет ли дубликатов, а уже потом переходить к конвертации.
#
#
# * Вместо цикличного `apply`, который за раз работает с одной строкой и при этом каждый раз вынужден проходиться по еще одной таблице, что очень долго и затратно, можно использовать довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем присоединить курс к нашей таблице с пользователями, применить данный метод к столбцу с выручкой и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```
#
# * Это исследовательская работа, а не скрипт, поэтому важно фиксировать свой ход мыслей, пояснять свои шаги и делать выводы относительно результатов, то есть вести последовательный сторителлинг, что зачем и почему мы делаем, что по итогу получаем, достигли ли нужного нам результата.
#
#
# </div>

# %% [markdown]
# ---
#
# #### **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %%
# проверка на пропущенные значения
def na_info(df, round_digits=1):
    '''
    Возвращает таблицу с количеством и процентом пропусков в столбцах датасета.
    '''
    count_na_name = 'Количество пропусков'
    res = pd.DataFrame({
        'Количество строк': len(df),
        count_na_name: df.isna().sum(),
        'Процент пропусков': round(df.isna().mean()*100, round_digits)
    }).sort_values(by=count_na_name, ascending=False)
    return res.query(f'`{count_na_name}` > 0')

na_info(df)
# Out:
#                  Количество строк  Количество пропусков  Процент пропусков
# days_since_prev            290611                 21933                7.5

# %% [markdown]
# Выгрузка произведена корректно - пропуски только в столбце days_since_prev и составляют 7.5%

# %%
# сделаем преобразование типов
df['device_type_canonical'] = df['device_type_canonical'].astype('category')
df['order_id'] = pd.to_numeric(df['order_id'], downcast='unsigned')
df['currency_code'] = df['currency_code'].astype('category')
df['tickets_count'] = pd.to_numeric(df['tickets_count'], downcast='unsigned')
df['days_since_prev'] = pd.to_numeric(df['days_since_prev'], downcast='float') #.astype('float32')
df['event_type_main'] = df['event_type_main'].astype('category')
df['revenue'] = df['revenue'].astype('float32')
df['revenue_rub'] = df['revenue_rub'].astype('float32')
df['event_id'] = pd.to_numeric(df['event_id'], downcast='unsigned') #.astype('int32')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  str
#  1   device_type_canonical  290611 non-null  category
#  2   order_id               290611 non-null  uint32
#  3   order_dt               290611 non-null  datetime64[us]
#  4   order_ts               290611 non-null  datetime64[us]
#  5   currency_code          290611 non-null  category
#  6   revenue                290611 non-null  float32
#  7   tickets_count          290611 non-null  uint8
#  8   days_since_prev        268678 non-null  float32
#  9   event_id               290611 non-null  uint32
#  10  event_name             290611 non-null  str
#  11  event_type_main        290611 non-null  category
#  12  service_name           290611 non-null  str
#  13  region_name            290611 non-null  str
# ...

# %%
df_size_mb = df.memory_usage(deep=False).sum()/1024/1024
print(f'Размер датафрейма до после изменения типов данных: {df_size_mb:.2f} МБ')
diff = df_original_size_mb - df_size_mb
print(f'Выигрыш в памяти: {diff:.2f} МБ {diff/df_original_size_mb*100:.2f} %')
# Out:
# Размер датафрейма до после изменения типов данных: 22.17 МБ
# Выигрыш в памяти: 11.09 МБ 33.33 %

# %% [markdown]
# Типы данных скорректированы. Датафрейм занимает 22 МБ в памяти, что на 33% меньше, чем в оригинале.
# Типы данных со временем остались без изменений: datetime64[ns] занимает 8 байт и предоставляет функции по работе с датой. Целесообразность преобразования в int32 колонки `order_dt` не подтверждается.

# %%
# проверяем номинальные столбцы (категории)
print(df['device_type_canonical'].value_counts())
print('----')
print(df['currency_code'].value_counts())
print('----')
print(df['event_type_main'].value_counts())
# Out:
# device_type_canonical
# mobile     232490
# desktop     58121
# Name: count, dtype: int64
# ----
# currency_code
# rub    285542
# kzt      5069
# Name: count, dtype: int64
# ----
# event_type_main
# концерты    115276
# театр        67321
# другое       65867
# спорт        21911
# стендап      13393
# выставки      4854
# ёлки          1989
# Name: count, dtype: int64

# %% [markdown]
# В категориальных колонках `device_type_canonical`, `currency_code`, `event_type_main` отсутствуют значения, обозначающие пропуски. Нормализация не требуется.

# %%
regions = df['region_name'].unique().tolist()
regions.sort()
regions
# Out:
# ['Белоярская область',
#  'Берестовский округ',
#  'Берёзовская область',
#  'Боровлянский край',
#  'Верховинская область',
#  'Верхозёрский край',
#  'Верхоречная область',
#  'Ветренский регион',
#  'Вишнёвский край',
#  'Глиногорская область',
#  'Голубевский округ',
#  'Горицветская область',
#  'Горноземский регион',
#  'Горностепной регион',
#  'Дальнеземская область',
#  'Дальнезорский край',
#  'Дубравная область',
#  'Залесский край',
#  'Заречная область',
#  'Зеленоградский округ',
#  'Златопольский округ',
#  'Золотоключевской край',
#  'Зоринский регион',
#  'Каменевский регион',
#  'Каменичская область',
#  'Каменноозёрный край',
#  'Каменноярский край',
#  'Каменополянский округ',
#  'Ключеводский округ',
#  'Кристаловская область',
#  'Кристальная область',
#  'Крутоводская область',
#  'Крутоводский регион',
#  'Лесноярский край',
#  'Лесодальний край',
#  'Лесополянская область',
#  'Лесостепной край',
#  'Лесоярская область',
#  'Луговая область',
# ...

# %% [markdown]
# За исключением значений, которые можно отнести к неявным дубликатам (хотя возможо это просто разные регионы):
# 'Речицкая область',
# 'Речицкий регион',
#
# колонка `region_name` не содержит подозрительных значений.

# %%
cities = df['city_name'].unique().tolist()
cities_normalized = [city.lower().strip() for city in cities]
print(f'Количество городов: {len(cities)}, количество нормализованных городов: {len(cities_normalized)}')
# Out:
# Количество городов: 352, количество нормализованных городов: 352

# %% [markdown]
# Колонка `city_name` также не содержит подозрительных значений. Нормализация не требуется.
# Оценим распределение числовых столбцов датасета (event_id исключаем, так как это просто числовой идентификатор):
# ```
# revenue
# tickets_count
# days_since_prev
# revenue_rub
# ```

# %%
def describe_num(df, column, title=None, xlabel=None, ylabel=None, pretty_column=None, bins=100, sizes=None):
    col_name = pretty_column if pretty_column else column
    title = f'Распределение {col_name}' if title is None else title
    xlabel = f'Значение {col_name}' if xlabel is None else xlabel
    ylabel = 'Количество' if ylabel is None else ylabel

    if df[column].dtype in ('float16', 'float32', 'float64'):
        print(df[column].agg(['min', 'max', 'mean', 'median', 'std']))
    else:
        print(df[column].describe())
    print('---')
    df[column].plot(
        title=title,
        xlabel=xlabel,
        ylabel=ylabel,
        kind='hist',
        bins=bins,
        figsize=sizes[0] if sizes else (12, 6)
    )

    plt.show()
    df[column].plot(
        title=title,
        xlabel=xlabel,
        vert=False,
        kind='box',
        figsize=sizes[1] if sizes else (12, 6)
    )
    plt.show()


describe_num(df, 'revenue_rub', pretty_column='выручки (руб)')
# Out:
# min         -90.760002
# max       81174.539062
# mean        555.571960
# median      351.140015
# std         875.498169
# Name: revenue_rub, dtype: float32
# ---

# %% [markdown]
# Значения выручки содержат явные выбросы - например 81174.5 рублей максимальное значение и -90.76 минимальное.
# Медиана выручки с заказа составляет 351 рубль.

# %%
# посмотрим на отрицательные значения выручки:
df[df['revenue_rub'] < 0]['revenue_rub'].describe()
# Out:
# count    381.000000
# mean      -2.492362
# std        5.065072
# min      -90.760002
# 25%       -3.450000
# 50%       -1.580000
# 75%       -0.650000
# max       -0.010000
# Name: revenue_rub, dtype: float64

# %% [markdown]
# Отрицательные значения необязательно являются ошибкой ввода.
# Оставляем в датасете, так как значений немного (381) и это может быть:
# - промо-акции или субсидированные билеты.
# - бонусные баллы, которые можно использовать для оплаты билетов.
# - возврат денежных средств.
#
# Для анализа лояльности важна сама покупка, а не только выручка.

# %%
describe_num(df, 'tickets_count', pretty_column='количества билетов', bins=50)
# Out:
# count    290611.000000
# mean          2.754311
# std           1.170620
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          57.000000
# Name: tickets_count, dtype: float64
# ---

# %% [markdown]
# Распределение количества билетов показывает, что в основном (в медиане) покупают 3 билета на мероприятия. При этом есть выбросы в виде значений > 30 (вероятно покупки на группу людей).

# %%
describe_num(df, 'days_since_prev', pretty_column='количества дней с последней покупки')
# Out:
# min         0.000000
# max       148.000000
# mean        3.222381
# median      0.000000
# std        11.350510
# Name: days_since_prev, dtype: float32
# ---

# %% [markdown]
# Распределение количества дней с момента последней покупки показывает, что множество значений сосредоточены вокруг нуля. Для более детального рассмотрения этой области построим гистограмму в окрестности нуля:

# %%
df[df['days_since_prev'] < 10]['days_since_prev'] \
    .plot(
        bins=10,
        kind='hist',
        title='Распределение количества дней с последней покупки в окрестности нуля',
        xlabel='Количество дней с последней покупки',
        ylabel='Частота'
    )
plt.show()

# %% [markdown]
# Действительно, более 175 тысяч значений данной колонки равняются 0, что может говорить о том, что пользователи в тот же день докупали билеты.
# Оценим эти данные в абсолютах и процентах и взглянем на них в датасете:

# %%
zero_days_num = len(df[df['days_since_prev'] == 0])
len(df_original)
print(f'Количество строк с нулевым количеством дней с предыдущего заказа: {zero_days_num} ({zero_days_num/len(df_original)*100:.0f}%)')
# Out:
# Количество строк с нулевым количеством дней с предыдущего заказа: 184052 (63%)

# %%
df[df['days_since_prev'] == 0].sort_values(by=['user_id', 'order_ts']).head(10)
# Out:
#             user_id device_type_canonical  order_id   order_dt  \
# 16  000cf0659a9f40f                mobile   6818017 2024-06-20
# 10  000cf0659a9f40f                mobile   6818249 2024-06-20
# 15  000cf0659a9f40f                mobile   6818220 2024-06-20
# 14  000cf0659a9f40f                mobile   6818046 2024-06-20
# 13  000cf0659a9f40f                mobile   6818075 2024-06-20
# 12  000cf0659a9f40f                mobile   6818104 2024-06-20
# 11  000cf0659a9f40f                mobile   6818133 2024-06-20
# 18  000cf0659a9f40f                mobile   6818162 2024-06-21
# 20  000cf0659a9f40f                mobile   6817959 2024-06-21
# 19  000cf0659a9f40f                mobile   6817988 2024-06-21
#
#               order_ts currency_code      revenue  tickets_count  \
# 16 2024-06-20 10:35:26           rub  1421.910034              4
# 10 2024-06-20 10:49:48           rub   710.950012              2
# 15 2024-06-20 10:56:16           rub  1421.910034              4
# ...

# %% [markdown]
# Выглядит интересно - один пользователь скупил на одно мероприятие по 2-4 билетов за несколько заказов в день.
# Более подробно посмотрим на этот момент при построении профиля пользователя.

# %% [markdown]
# А сейчас вернемся к выбросам в колонке `revenue_rub` и фильтруем их по 99 процентилю:

# %%
outliers = df['revenue_rub'].quantile(0.99)
print(f"99-й процентиль по revenue_rub: {outliers}")
df = df[df['revenue_rub'] < outliers]

removed_lines = len(df_original) - len(df)
removed_lines_pct = round(removed_lines / len(df_original) * 100, 2)
print(f"Удалено строк выбросами по revenue_rub: {removed_lines} ({removed_lines_pct}%)")
# Out:
# 99-й процентиль по revenue_rub: 2628.419921875
# Удалено строк выбросами по revenue_rub: 3007 (1.03%)

# %% [markdown]
# Исследуем дубликаты.

# %%
print('Количество явных дубликатов:', df.duplicated().sum())

def count_duplicates(df, columns = []):
    dups_full = df[df.duplicated(subset=columns, keep=False)]
    dups_keep_first = df[df.duplicated(subset=columns, keep='first')]
    print(f'Количество дубликатов (без дедупликации) по {columns}:', len(dups_full))
    print(f'Количество дубликатов по {columns}:', len(dups_keep_first))
    return dups_full
# Out:
# Количество явных дубликатов: 0

# %%
count_duplicates(df, columns=['user_id', 'order_ts'])
# Out:
# Количество дубликатов (без дедупликации) по ['user_id', 'order_ts']: 323
# Количество дубликатов по ['user_id', 'order_ts']: 169
#                 user_id device_type_canonical  order_id   order_dt  \
# 4351    02ea4583333f064                mobile   1158638 2024-08-23
# 4353    02ea4583333f064                mobile   1158696 2024-08-23
# 5701    02ea4583333f064                mobile   1536363 2024-10-16
# 5710    02ea4583333f064                mobile   5271215 2024-10-16
# 6070    02ea4583333f064                mobile   4952505 2024-10-27
# ...                 ...                   ...       ...        ...
# 285388  fd4d47438ebb946               desktop   8547809 2024-06-19
# 285942  fd4d47438ebb946                mobile   6201361 2024-09-23
# 285943  fd4d47438ebb946                mobile   6201419 2024-09-23
# 289318  fe237d2cfd6e503               desktop   7566014 2024-10-31
# 289356  fe237d2cfd6e503               desktop   2376638 2024-10-31
#
# ...

# %% [markdown]
# В датасете есть неявные дубликаты: 323 строки без дедупликации и 169 строк с дедупликацией.
# Дубликаты выявлены следующим образом: в одну секунду времени обычный пользователь не оформляет по несколько билетов на сайте Афиши. Вероятно, эти записи являются ошибкой ввода данных.
# Их не очень много, поэтому можно ими пренебречь и удалить из датасета.

# %%
df.drop_duplicates(subset=['user_id', 'order_ts'], keep='first', inplace=True)
removed_lines = len(df_original) - len(df)
removed_lines_pct = round(removed_lines / len(df_original) * 100, 2)
print(f"Удалено строк выбросами по revenue_rub и с неявными дубликатами по user_id и order_ts: {removed_lines} ({removed_lines_pct}%)")
# Out:
# Удалено строк выбросами по revenue_rub и с неявными дубликатами по user_id и order_ts: 3176 (1.09%)

# %% [markdown]
# #### Вывод по разделу 2 (предобработка данных):
# - Часть данных в колонке revenue приведена в казахстанских тенге. Чтобы оценивать данные по выручке единообразно в одной валюте, был создан новый столбец revenue_rub, в который был произведен расчет выручки в рублях по курсу на дату совершения заказа.
# - Проведен анализ пропущенных значений. Ожидаемо они присутствуют только в столбце `days_since_prev` (в 22 тыс. строк, 7.5%) - количество дней с предыдущего заказа. Данный столбец имеет пропуски у пользователей с 1 заказом.
# - Удалено около 3000 строк с выбросами в колонке выручки и еще около 100 строк дубликатов по user_id и order_ts, что составляет 1% от датасета.
# - Произведена корректировка типов данных, в том числе изменены размерности, что сэкономило 33% занимаемой памяти датасетом (22 МБ вместо 33 МБ).
# - Проанализированы колонки `region_name` и `city_name` на предмет дубликатов - не выявлено.
# - Построены графики распределений числовых столбцов:
#     - Выручка:
#         - Медиана выручки составляет 351 рубль
#         - Выручка содержит выбросы и отрицательные значения. Отрицательные значения могут быть следствием применения скидок.
#         - Датасет очищен от выбросов по колонке выручки по 99 перцентилю, вследствие чего было удалено около 3 тыс./1% строк датасета.
#     - Количество дней с последнего заказа:
#         - Выявлено большое количество (182048/63%) строк в таблице, в которых количество дней с предыдущего заказа равно нулю. Исследование этого феномена отложено на следующий раздел.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Предобработка данных <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> C задачей справились, предобработку провели!
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Было бы не лишним убедиться, что пропуски имеются только в количестве дней между заказами у первых заказов пользователей, то есть что проблемы здесь нет.
#
#
# * Снизить размерность типа для количественных показателей и перейти к типу `category` для номинальных имеет смысл уже после проведения предобработки, когда мы избавимся от ошибок и экстремальных значений. Количество дней между заказами тоже можно сделать целочисленным - заранее перевести в `Int`, который, в отличие от `int`, дозволяет присутствие пропусков, а уже потом даункастить.
#
#
# * Билетные операторы задейтсвуются в дальнейшем анализе, но сейчас остались непроверенными на предмет корректности.
#
#
# * Для аккуратности боксплот можно сделать чуть поизящнее ([пример](https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/)). Для лучшего ориентирования внутри графика стоит добавлять сетку.
#
#
# * Относительно отрицательных значений выручки - возможно, это какие-то возвраты. По-хорошему, их тоже следовало бы исключить, чтобы не завышать количество валидных транзакций на пользователя.
#
#
# * После борьбы с дубликатами нужно пересчитать признак с количеством дней между заказами.
#
#
# * Для лучшей навигации по проекту было бы неплохо создать четкую последовательность действий, выделить тематические подразделы.
#
#
# * Обрати внимание, что если не ограничивать количество выводимой информации, то вывод ограничится только при отображении, но в json (в виде которых хранятся jupyter-ноутбуки) на диске будут все данные, что будет тормозить открытие и работу тетрадки. Чтобы такого не происходило, следует ограничивать вывод несколькими строками: `head`, `tail`, `sample`.
#
#
# * Если выводим какие-то значения на печать, то стоит их форматировать. Для красоты и удобства дробные значения лучше округлять до знаков, которые могут представлять для нас интерес.
#
#
# * Согласно стандартам оформления кода не стоит делать строки длиной более 79 символов, это портит его читаемость, вынуждает прокручивать ячейку.
#
# </div>

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# #### **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
# произведем сортировку датасета по времени совершения заказа
df = df.sort_values(by=['order_ts'])
df.head(3)
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 285281  fd4d47438ebb946                mobile   7565637 2024-06-01
# 285282  fd4d47438ebb946                mobile   7565521 2024-06-01
# 118843  57ef0a1905ac488                mobile   6670842 2024-06-01
#
#                   order_ts currency_code      revenue  tickets_count  \
# 285281 2024-06-01 00:00:42           rub  1083.150024              4
# 285282 2024-06-01 00:01:30           rub   812.359985              3
# 118843 2024-06-01 00:01:58           rub  2091.310059              4
#
#         days_since_prev  event_id                            event_name  \
# 285281              0.0    131671  f4431442-3d97-452d-a6d6-eadf6bd34378
# 285282              0.0    131671  f4431442-3d97-452d-a6d6-eadf6bd34378
# 118843              NaN    375861  ba89f19f-e73c-4d74-ab35-b9c023bb4de6
#
#        event_type_main   service_name         region_name   city_name  \
# ...

# %%
# введем новый датасет - профиль пользователя. В нем каждая строка - это пользователь,
# ключевой колонкой будет user_id, а в остальных - статистики по пользователю
df_users = df.groupby(['user_id']).agg(
    first_order_ts = ('order_ts', 'min'), # дата первого заказа;
    last_order_ts = ('order_ts', 'max'), # дата последнего заказа;
    orders_count = ('order_id', 'count'), # общее количество заказов

    avg_revenue = ('revenue_rub', 'mean'), # средняя выручка с одного заказа в рублях;
    avg_tickets_count = ('tickets_count', 'mean'), # среднее количество билетов в заказе;
    total_tickets_count = ('tickets_count', 'sum'), # общее количество купленных билетов;
    avg_order_delay = ('days_since_prev', 'mean'), # среднее время между заказами
    # - устройство, с которого был сделан первый заказ;
    # - регион, в котором был сделан первый заказ;
    # - билетного партнёра, к которому обращались при первом заказе;
    # - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
).reset_index()
df_users.head(5)
# Out:
#            user_id      first_order_ts       last_order_ts  orders_count  \
# 0  0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03             1
# 1  0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02             2
# 2  000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00             3
# 3  00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48             1
# 4  000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04             2
#
#    avg_revenue  avg_tickets_count  total_tickets_count  avg_order_delay
# 0  1521.939941           4.000000                    4              NaN
# 1   774.010010           3.000000                    6             75.0
# 2   767.213379           2.666667                    8             51.0
# 3   917.830017           4.000000                    4              NaN
# 4    61.309998           1.500000                    3             16.0

# %% [markdown]
# Чтобы найти указанные параметры первого заказа, присоединим данные исходного датасета в профили пользователей по `user_id` и `first_order_ts`

# %%
# предварительно проверим дубликаты по этим колонкам:
df[df.duplicated(subset=['user_id', 'order_ts'], keep=False)].sort_values('order_ts')
# Out:
# Empty DataFrame
# Columns: [user_id, device_type_canonical, order_id, order_dt, order_ts, currency_code, revenue, tickets_count, days_since_prev, event_id, event_name, event_type_main, service_name, region_name, city_name, revenue_rub]
# Index: []

# %%
# предварительно проверим дубли по этим колонкам:
grouped = df.groupby(['user_id', 'order_ts'])['user_id'].agg('count')
grouped[grouped > 1]
pd.DataFrame(grouped[grouped > 1])
# Out:
# Empty DataFrame
# Columns: [user_id]
# Index: []

# %% [markdown]
# Сейчас дублей нет, но эта проверка привела к идее выделить такие дубликаты и удалить их из датасета

# %%
df_users = df_users.merge(
    df,
    left_on=['user_id', 'first_order_ts'],
    right_on=['user_id', 'order_ts'],
    how='left',
)[[
    'user_id',
    'first_order_ts',
    'last_order_ts',
    'orders_count',
    'avg_revenue',
    'avg_tickets_count',
    'total_tickets_count',
    'avg_order_delay',
    'device_type_canonical', # - устройство, с которого был сделан первый заказ;
    'region_name', # - регион, в котором был сделан первый заказ;
    'service_name', # - билетного партнёра, к которому обращались при первом заказе;
    'event_type_main', # - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
]]

# %%
# Добавим еще бинарные признаки
df_users['is_five'] = df_users['orders_count'] >= 5 # совершил ли пользователь 5 и более заказов.
df_users['is_two'] = df_users['orders_count'] >= 2 # совершил ли пользователь 2 и более заказа;
df_users.head(5)
# Out:
#            user_id      first_order_ts       last_order_ts  orders_count  \
# 0  0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03             1
# 1  0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02             2
# 2  000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00             3
# 3  00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48             1
# 4  000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04             2
#
#    avg_revenue  avg_tickets_count  total_tickets_count  avg_order_delay  \
# 0  1521.939941           4.000000                    4              NaN
# 1   774.010010           3.000000                    6             75.0
# 2   767.213379           2.666667                    8             51.0
# 3   917.830017           4.000000                    4              NaN
# 4    61.309998           1.500000                    3             16.0
#
#   device_type_canonical           region_name   service_name event_type_main  \
# ...

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Создание профиля пользователя <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
#
# <b>Отлично ✅:</b> Результат корректный!
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
#
# * Есть удобный агрегирующий метод `first`, его можно использовать при группировке наравне с остальными агрегатами. Как раз для его использования и требовалась сортировка по времени.
#
#
# * Также есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и жанр мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
#
# * Напоминаю про моменты, которые уже поясняла в предыдущих комментариях: вывод неограниченного количества строк.
#
# </div>

# %% [markdown]
# ### 🎁 СНГ - такое решение гораздо лучше. Спасибо, приму на вооружение

# %% [markdown]
# ---
#
# #### **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
print(
    f'Общее число пользователей в выборке: {len(df_users)}\n',
    f'Cредняя выручка с одного заказа: {df_users["avg_revenue"].mean():.2f}\n',
    f'Доля пользователей, совершивших 2 и более заказа: {df_users["is_two"].mean():.2f}\n',
    f'Доля пользователей, совершивших 5 и более заказа: {df_users["is_five"].mean():.2f}\n',
)

print(
    f'Общее число заказов: {df_users["orders_count"].sum()}\n',
    f'Среднее число билетов в заказе: {df_users["total_tickets_count"].sum()/df_users["orders_count"].sum():.2f}\n',
    f'Среднее число билетов в заказе (способ 2): {df_users["avg_tickets_count"].mean():.2f}\n',
    f'Cреднее количество дней между покупками: {df_users["avg_order_delay"].mean():.2f}\n',
    f'Медианное число билетов в заказе: {df_users["avg_tickets_count"].median():.2f}\n',
    f'Медианное количество дней между покупками: {df_users["avg_order_delay"].median():.2f}\n',
)
# Out:
# Общее число пользователей в выборке: 21848
#  Cредняя выручка с одного заказа: 543.38
#  Доля пользователей, совершивших 2 и более заказа: 0.62
#  Доля пользователей, совершивших 5 и более заказа: 0.29
#
# Общее число заказов: 287435
#  Среднее число билетов в заказе: 2.74
#  Среднее число билетов в заказе (способ 2): 2.74
#  Cреднее количество дней между покупками: 15.87
#  Медианное число билетов в заказе: 2.75
#  Медианное количество дней между покупками: 8.00

# %% [markdown]
# Число пользователей - более 20 тысяч. 62% из них сделали 2 и более заказов. Этого достаточно для анализа.
#
# Оценим есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов:

# %%
df_users[['orders_count', 'avg_tickets_count', 'total_tickets_count']].describe()
# Out:
#        orders_count  avg_tickets_count  total_tickets_count
# count  21848.000000       21848.000000         21848.000000
# mean      13.156124           2.742913            36.052179
# std      121.487813           0.913364           339.354337
# min        1.000000           1.000000             1.000000
# 25%        1.000000           2.000000             3.000000
# 50%        2.000000           2.750000             6.000000
# 75%        5.000000           3.076923            15.000000
# max    10160.000000          11.000000         29082.000000

# %% [markdown]
# Максимальные значения количества заказов = 10160 и общее количество купленных билетов = 29082 обращают на себя внимание. Напротив, среднее число заказов в билете равно 2.7, при этом максимальное среднее число билетов в заказе - 11, не вызывает подозрений.
#
# Найдем таких пользователей с большим количеством заказов и купленных билетов:

# %%
df_users[df_users['orders_count'] > 3000].sort_values('orders_count', ascending=False).head(5)
# Out:
#                user_id      first_order_ts       last_order_ts  orders_count  \
# 980    0beb8fc0c0a9ce1 2024-06-01 00:18:28 2024-10-31 23:28:28         10160
# 2053   18e9aead0a393e7 2024-06-01 00:04:54 2024-10-31 23:49:44          4343
# 11069  8187dac4be757a0 2024-06-01 10:53:53 2024-10-31 23:30:10          4016
# 5413   3ee7dc2e115847f 2024-06-01 09:13:31 2024-10-31 23:42:07          3786
# 10806  7eb4fc207ecc10f 2024-06-01 09:10:33 2024-10-31 23:58:55          3692
#
#        avg_revenue  avg_tickets_count  total_tickets_count  avg_order_delay  \
# 980     504.155853           2.862402                29082         0.014864
# 2053    493.577759           2.787704                12107         0.034316
# 11069   537.346130           2.748257                11037         0.037609
# 5413    536.908630           2.764659                10467         0.039894
# 10806   540.625671           2.958017                10921         0.040639
#
# ...

# %% [markdown]
# Среди пользователей выделяется `user_id=0beb8fc0c0a9ce1`, который сделал 10160 заказов и купил всего 29082 билетов. Возможно это партнер сервиса, либо мы имеем дело с фродом.
#
# Исследуем, какая доля пользователей имеет аномальное число заказов. Для посмотрим на распределение количества заказов для таких пользователей, отрезав частотных пользователей с небольшим количеством заказов:

# %%
describe_num(df_users[df_users['orders_count'] > 50], 'orders_count', bins=300, pretty_column='количества заказов (аномальные)')
# Out:
# count      705.000000
# mean       266.611348
# std        624.550859
# min         51.000000
# 25%         67.000000
# 50%         99.000000
# 75%        194.000000
# max      10160.000000
# Name: orders_count, dtype: float64
# ---

# %% [markdown]
# Действительно, существует группа пользователей, которые совершают аномально большое количество заказов. Они выделяются на диаграмме размаха и гистограмме.
# Их не очень много, и они не должны значительно влиять на медианные значения количества заказов и среднего времени между заказами. Проверим это:

# %%
# Сохраним оригинальный датафрейм с профилями пользователей для сравнения размеров
df_users_original = df_users.copy()

# %%
orders_count_pct99 = df_users['orders_count'].quantile(0.99)

df_users = df_users[df_users['orders_count'] < orders_count_pct99]
diff = len(df_users_original) - len(df_users)

print(f'Удалено {diff} ({diff/len(df_users_original)*100:.2f}%) профилей пользователей с аномальным количеством заказов {orders_count_pct99}')
# Out:
# Удалено 220 (1.01%) профилей пользователей с аномальным количеством заказов 152.0

# %%
print(
    f'99 процентиль orders_count до удаления: {df_users_original["orders_count"].quantile(0.99)}',
    f'медиана orders_count до удаления: {df_users_original["orders_count"].quantile(0.5)}',
    f'медиана orders_count после удаления: {df_users["orders_count"].quantile(0.5)}',
    f'медиана avg_order_delay до удаления: {df_users_original["avg_order_delay"].quantile(0.5)}',
    f'медиана avg_order_delay после удаления: {df_users["avg_order_delay"].quantile(0.5):.2f}',
    sep='\n'
)
# Out:
# 99 процентиль orders_count до удаления: 152.0
# медиана orders_count до удаления: 2.0
# медиана orders_count после удаления: 2.0
# медиана avg_order_delay до удаления: 8.0
# медиана avg_order_delay после удаления: 8.38

# %%
describe_num(df_users, 'orders_count', pretty_column='количества заказов (после удаления аномальных)')
# Out:
# count    21628.000000
# mean         6.468559
# std         14.165549
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        151.000000
# Name: orders_count, dtype: float64
# ---

# %% [markdown]
# После удаления примерно 1% пользователей с аномально большим количеством заказов, медиана количества заказов не изменилась - 2, медиана количества дней между заказами изменилась незначительно - было 8.0, стало 8.4.

# %% [markdown]
# Проверим, какая доля исходного датасета с заказами выпадает из исследования при удалении указанных пользовательских профилей:

# %%
original_users = set(df_users_original['user_id'].tolist())
user_after_remove = set(df_users['user_id'].tolist())
removed_users = original_users - user_after_remove
removed_users_orders_count = len(df[df['user_id'].isin(removed_users)])
diff = len(df) - removed_users_orders_count
print(
    f'Из заказов удалено {diff} ({diff/len(df)*100:.2f}%)строк от ',
    f'{len(removed_users)} пользователей с большим количеством заказов")',
)
# Out:
# Из заказов удалено 139902 (48.67%)строк от  220 пользователей с большим количеством заказов")

# %% [markdown]
# Это печальное известие: почти половина заказов в датасете осуществлена 1% пользователей с аномально большим количеством заказов. То есть, таких пользователей все-таки необходимо учитывать при анализе и не удалять из датасета. В следующих разделах посмотрим на них пристальнее.

# %%
# восстанавливаем профили пользователей с большим количеством заказов:
df_users = df_users_original

# %% [markdown]
# После удаления перекупов статистики в профилях пользователя стали выглядеть чуть правдоподобнее, но не сильно изменились (дифф в пределах 5% от исходных значений), но все же продолжим анализ на основе очищенного датасета.

# %% [markdown]
# #### ~~Вывод по разделу 3 (пользовательский профиль)~~ UPD обновлен ниже:
# ~~В данном разделе был построен датасет с пользовательскими профилями - статистиками по каждому пользователю.~~
#
# Ключевые инсайты:
# - ~~Число пользователей в датасете - более 20к, 62% из них сделали 2 и более заказов, что достаточно для анализа. 30% пользователей совершили более 5 заказов.~~
# - ~~Была обнаружена кагорта пользователей совершающих аномально большое количество заказов. Среди пользователей выделяется `user_id=0beb8fc0c0a9ce1`, который сделал 10160 заказов и купил всего 29082 билетов.~~
# - ~~При попытке отфильтровать данных пользователей выяснилось, что они совершили около половины всех заказов в датасете, что исключает возможность их удаления из датасета. Они будут рассмотрены отдельно в следующем разделе.~~

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ пользовательских профилей <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Выполнены все необходимые шаги!
# </div>
#
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> С решением по выбросам все же не соглашусь. Сейчас мы хотим изучить поведение клиентов, чтобы на основе полученных инсайтов предложить стратегии по привлечению новых и удержанию старых клиентов. Привлечение и удержание перекупов не в интересах бизнеса. Даже если они составляют значимую долю выручки, с ними, как правило, стараются бороться. Почему? (1) Это упущенная выгода - перекупы скупают билеты по дешевке, перепродают дороже и забирают эту выгоду себе, без перекупов билетный агрегатор мог бы заработать больше, особенно в долгосрочной перспективе, если грамотно выстроит отношения с клиентами, которые рады будут возвращаться в качественный и удобный сервис за новыми заказами. (2) Это репутационные риски - недовольными остаются как потребители, которые сталкиваются с завышенными ценами у перекупов, а иногда и вовсе с актами мошенничества, так и билетные представители, на которых в том числе обрушивается недовольство потребителей. Часто для продолжения сотрудничества с агрегатором важным критерием для билетных представителей является возможность обеспечения чистого и стабильного трафика. (3) Высокая нагрузка на сервер в момент массового скупа ботами, которая может положить всю систему, на восстановление которой потребуется время.
#
# Поэтому все же буду настаивать на том, что поддержка спекуляций не есть хорошо, и нам сейчас лучше сосредоточиться на рядовых пользователях.
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
#
#
# * Было бы не лишним также проверить, насколько изменились показатели возвращаемости и средней выручки после фильтрации.
#
#
# * Напоминаю про моменты, которые уже поясняла в предыдущих комментариях: длина строки кода.
#
# </div>

# %% [markdown]
# UPD: 🎁 СНГ - я не был уверен, что это мошенники (было предположение, что это партнерские аккаунты), поэтому не удалял таких пользователей из датасета. Но твои замечания о том, что это перекупы, я принял: удалим перекупов.

# %% [markdown]
# Чтобы удалить перекупов, нужно чуть более точно выделить их группу среди пользователей. Просто отделив 99 перцентиль недостаточно.
# Проверим распределение количества заказов среди пользователей. В датасете данные за 5 месяцев - с июня по октябрь 2024 года. Физическим можно успеть сходить в месяц на 30 мероприятий вдвоем, потребуется 30*2*5=300 билетов, и 150 заказов. Возьмем это за ориентир верхней границы использования сервиса нормальным пользователем.

# %% [markdown]
# Построим столбчатую диаграмму распределения количества заказов среди подозрительных пользователей:

# %%
high_water_mark_orders = 150
mask_unnormal_users_orders = df_users['orders_count'] > high_water_mark_orders
unnormal_users_by_orders = df_users[mask_unnormal_users_orders]
print(f'Найдено {len(unnormal_users_by_orders)}',
    f'пользователей с количеством заказов более {high_water_mark_orders}')
# Out:
# Найдено 222 пользователей с количеством заказов более 150

# %% [markdown]
# А теперь найдем пользователей с большим количеством заказов и пересечем их с пользователями, которые совершили более 150 заказов

# %%
high_water_mark_tickets = 300
mask_unnormal_users_by_tickets = (
    df_users['total_tickets_count'] > high_water_mark_tickets
)

unnormal_users_by_tickets = df_users[mask_unnormal_users_by_tickets]
print(f'Найдено {len(unnormal_users_by_tickets)}',
    f'пользователей с количеством билетов более {high_water_mark_tickets}')
# Out:
# Найдено 317 пользователей с количеством билетов более 300

# %%
# пресечем множество пользователей с большим количеством заказов и билетов
final_unnormal_users = set(unnormal_users_by_tickets['user_id'].to_list()) \
    .intersection(set(unnormal_users_by_orders['user_id'].to_list()))
print(f'Найдено {len(final_unnormal_users)}',
    f'пользователей с количеством заказов и билетов более {high_water_mark_orders} и {high_water_mark_tickets}')
# Out:
# Найдено 222 пользователей с количеством заказов и билетов более 150 и 300

# %%
# удалим пользователей-перекуповиз датасета
df_users = df_users[~df_users['user_id'].isin(final_unnormal_users)]

# статистика удаления:
diff = len(df_users_original) - len(df_users)
diff_pct = round(diff / len(df_users_original) * 100, 2)
print(f'Удалено {diff} ({diff_pct}%) пользователей-перекупов',
    f'из {len(df_users_original)} пользователей')
# Out:
# Удалено 222 (1.02%) пользователей-перекупов из 21848 пользователей

# %% [markdown]
# Таким образом мы вычислили 222 пользователя с аномально большим количеством заказов и купленных билетов и удалили их из датасета с профилями пользователей. Датасет уменьшился на 1% . Это допустимо для анализа пользовательских профилей.

# %% [markdown]
# Пересчитаем статистики по профилям пользователей и проверим, как изменились показатели после удаления перекупов

# %%
avg_tickets = (
    df_users["total_tickets_count"].sum() /
    df_users["orders_count"].sum()
)
avg_tickets_before = (
    df_users_original["total_tickets_count"].sum() /
    df_users_original["orders_count"].sum()
)
print(
    '   Статистики пользователей после удаления перекупов (было/стало):',
    f'Общее число пользователей: {len(df_users_original)}/{len(df_users)}',
    f'Cредняя выручка с одного заказа: '
    f'{df_users_original["avg_revenue"].mean():.2f}/{df_users["avg_revenue"].mean():.2f}',
    f'Доля пользователей, совершивших 2 и более заказа: '
    f'{df_users_original["is_two"].mean():.2f}/{df_users["is_two"].mean():.2f}',
    f'Доля пользователей, совершивших 5 и более заказа: '
    f'{df_users_original["is_five"].mean():.2f}/{df_users["is_five"].mean():.2f}',
    f'Общее число заказов: '
    f'{df_users_original["orders_count"].sum()}/{df_users["orders_count"].sum()}',
    f'Среднее число билетов в заказе: '
    f'{df_users_original["avg_tickets_count"].mean():.2f}/{df_users["avg_tickets_count"].mean():.2f}',
    f'Среднее число билетов в заказе (способ 2): '
    f'{avg_tickets_before:.2f}/{avg_tickets:.2f}',
    f'Медианное число билетов в заказе: '
    f'{df_users_original["avg_tickets_count"].median():.2f}/{df_users["avg_tickets_count"].median():.2f}',
    f'Cреднее количество дней между покупками: '
    f'{df_users_original["avg_order_delay"].mean():.2f}/{df_users["avg_order_delay"].mean():.2f}',
    f'Медианное количество дней между покупками: '
    f'{df_users_original["avg_order_delay"].median():.2f}/{df_users["avg_order_delay"].median():.2f}',
    sep='\n'
)
# Out:
#    Статистики пользователей после удаления перекупов (было/стало):
# Общее число пользователей: 21848/21626
# Cредняя выручка с одного заказа: 543.38/543.70
# Доля пользователей, совершивших 2 и более заказа: 0.62/0.61
# Доля пользователей, совершивших 5 и более заказа: 0.29/0.28
# Общее число заказов: 287435/139600
# Среднее число билетов в заказе: 2.74/2.74
# Среднее число билетов в заказе (способ 2): 2.74/2.73
# Медианное число билетов в заказе: 2.75/2.75
# Cреднее количество дней между покупками: 15.87/16.12
# Медианное количество дней между покупками: 8.00/8.39

# %% [markdown]
# #### Финальный вывод по разделу 3 (пользовательский профиль)
# В данном разделе был построен датасет с пользовательскими профилями - статистиками по каждому пользователю.
#
# Ключевые инсайты:
# - Число пользователей в датасете - более 20к, 61% из них сделали 2 и более заказов, что достаточно для анализа. 28% пользователей совершили более 5 заказов.
# - Была обнаружена кагорта пользователей совершающих аномально большое количество заказов (около 50% от общего числа заказов в Афише). Предположительно это перекупы. 222 (1%) пользователя были удалены из датасета.
# - Средняя выручка с заказа в Афише - 544 рубля
# - Среднее число билетов в заказе - 2.74
# - Среднее число дней между заказами - 16. Медианное - 8.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# #### **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
def analyze_segment(
    segment=[],
    pretty_column=None,
    rot=0,
    percentile=None
):
    users_by_segment = df_users.groupby(
        segment, observed=True
    ).agg(
        users_count=('user_id', 'count')
    ).sort_values(
        by='users_count', ascending=False
    ).reset_index()
    users_share_by_segment = df_users[segment].value_counts(
        normalize=True
    ).reset_index(name='users_share')
    users_by_segment['users_share'] = (
        users_share_by_segment['users_share']
    )
    users_by_segment.index = users_by_segment[segment]
    users_by_segment.drop(columns=segment, inplace=True)
    users_by_segment['users_share'] = users_by_segment['users_share'].round(2)
    display(users_by_segment)

    if percentile:
        threshold = (
            users_by_segment['users_count'].quantile(percentile)
        )
        users_by_segment = users_by_segment[
            users_by_segment['users_count'] >= threshold
        ]

    title = (
        f'Сегменты пользователей по '
        f'{pretty_column if pretty_column else segment}'
    )
    users_by_segment.sort_values(
        'users_count', ascending=False
    ).plot(
        y='users_count',
        kind='bar',
        title=title,
        xlabel='Сегмент пользователей',
        ylabel='Количество пользователей',
        legend=False,
        figsize=(6, 3),
        rot=rot,
    )
    plt.show()
    return users_by_segment

analyze_segment('event_type_main', pretty_column='типу события')
analyze_segment(
    'device_type_canonical',
    pretty_column='типу устройства'
)
analyze_segment(
    'service_name',
    pretty_column='билетному оператору (90 процентиль)',
    rot=90,
    percentile=0.5
)
segment_region = analyze_segment(
    'region_name',
    pretty_column='региону (80 процентиль)',
    rot=90,
    percentile=0.8
)
# Out:
#                  users_count  users_share
# event_type_main
# концерты                9548         0.44
# другое                  5427         0.25
# театр                   4239         0.20
# стендап                 1110         0.05
# спорт                    794         0.04
# выставки                 413         0.02
# ёлки                      95         0.00
#                        users_count  users_share
# device_type_canonical
# mobile                       17917         0.83
# desktop                       3709         0.17
#                         users_count  users_share
# service_name
# Билеты без проблем             5184         0.24
# Мой билет                      2957         0.14
# Лови билет!                    2810         0.13
# Билеты в руки                  2558         0.12
# Облачко                        2179         0.10
# Весь в билетах                 1285         0.06
# Лучшие билеты                  1184         0.05
# ...

# %% [markdown]
# Пользователи распределены по сегментам неравномерно:
# - По типу мероприятия (абсолюты и доля):
# ```
#     концерты	9548	0.44
#     другое	5427	0.25
#     театр	4239	0.20
# ```
# - По типу устройства:
# ```
#     mobile	17917	0.83
#     desktop	3709	0.17
# ```
# - По оператору:
# ```
#     Билеты без проблем	5184	0.24
#     Мой билет	        2957	0.14
#     Лови билет!	        2810	0.13
#     Билеты в руки	2558	0.12
#     Облачко	        2179	0.10
#     Весь в билетах	1285	0.06
# ```
# - По региону:
# ```
#     Каменевский регион	        7086	0.33
#     Североярская область	3767	0.17
#     Широковская область	        1224	0.06
#     Озернинский край	        675	0.03
#     Малиновоярский округ	525	0.02
# ```
#
# Итого:
#
# - на концерты покупают наибольшее количество пользователей - почти 10к и 44%, "другое" - 5к и 25%, "театр" - 4к и 20%
# - большинство пользователей с мобильных устройств - почти 18к и 83%
# - наиболее популярный оператор - "Билеты без проблем" 5к и 24%. Остальные занимают долю менее 15%.
# - наиболее крупные регионы - Каменевский 7к и 33%, Североярская область 4к и 17% (Скорее всего это Москва и Санкт-Петербург)

# %% [markdown]
# ---
#
# #### **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
def segment_by_is_two(segment = [], pretty_segment = None, rot=90, topN = None, figsize=None):
    users_by_segment_by_is_two = df_users.groupby(segment, observed=True).agg(
        user_count = ('user_id', 'count'),
        is_two_count = ('is_two', 'sum'),
    )
    users_by_segment_by_is_two['is_two_share'] = round(users_by_segment_by_is_two['is_two_count'] / users_by_segment_by_is_two['user_count'], 2)
    users_by_segment_by_is_two_full = users_by_segment_by_is_two.copy()
    if topN:
        # print(f'segments before resizing to {topN} segments: {len(users_by_segment_by_is_two)}')
        users_by_segment_by_is_two.sort_values('user_count', ascending=False, inplace=True)
        users_by_segment_by_is_two = users_by_segment_by_is_two.iloc[:topN]
        # print(f'segments after resizing to {topN} segments: {len(users_by_segment_by_is_two)}')

    users_by_segment_by_is_two.sort_values('is_two_share', ascending=False, inplace=True)

    display(users_by_segment_by_is_two)

    filtered_pct = f',\nучитывая топ-{topN} сегментов по количеству пользователей' if topN else ''



    plot = users_by_segment_by_is_two.plot(
        kind='bar',
        y='is_two_share',
        title=f'Доля пользователей с 2+ заказами в сегменте "{pretty_segment if pretty_segment else segment}"{filtered_pct}',
        xlabel=f'{pretty_segment if pretty_segment else segment}',
        ylabel='Доля пользователей',
        legend=False,
        rot=rot,
        figsize=figsize if figsize else (7, 3)
    )

    def hline(value, title, color='red'):
        plot.text(0, value + 0.001, f'{title} {value:.2f}', ha='left', va='bottom', color=color)
        plot.axhline(value, color=color, linestyle='--')


    hline(users_by_segment_by_is_two['is_two_share'].mean(), 'Среднее значение', color='blue')

    plt.show()

    return users_by_segment_by_is_two_full

segment_event = segment_by_is_two(['event_type_main'], pretty_segment='тип события', rot=0)
segment_device = segment_by_is_two(['device_type_canonical'], pretty_segment='тип устройства', rot=0)
segment_region = segment_by_is_two(['region_name'], pretty_segment='регион', rot=45, topN=20, figsize=(10, 4))
segment_operator = segment_by_is_two(['service_name'], pretty_segment='оператор', rot=45, topN=10, figsize=(10, 4))
# Out:
#                  user_count  is_two_count  is_two_share
# event_type_main
# выставки                413           264          0.64
# театр                  4239          2687          0.63
# концерты               9548          5902          0.62
# стендап                1110           676          0.61
# другое                 5427          3236          0.60
# спорт                   794           443          0.56
# ёлки                     95            53          0.56
#                        user_count  is_two_count  is_two_share
# device_type_canonical
# desktop                      3709          2368          0.64
# mobile                      17917         10893          0.61
#                            user_count  is_two_count  is_two_share
# region_name
# Горицветская область              247           165          0.67
# Шанырский регион                  499           335          0.67
# Светополянский округ              456           299          0.66
# ...

# %% [markdown]
# Если оценивать долю пользователей, купивших 2 и более билетов в наиболее массовых элементах сегмента, то:
# - Лучше всего этот показатель на выставках (64%), в театрах (63%), потом идут концерты (62%), стендап (61%), другое (60%)
# - Десктопные устройства (64%) и чуть ниже мобильные устройства (61%), но в целом, похоже.
# - В регионах: если брать самые большие регионы - Североярская область - 64% (по нашему предположению, это Санкт-Петербург), Каменевский регион (как бы Москва) - 62%. Спор двух столиц за культурность (в данном контексте - за повторные походы в культурные места) разрешается в пользу Санкт-Петербурга. Есть еще Широковская область (1224 пользователя, то есть примерно половина Санкт-Петербурга), там этот показатель 65%. Интересно было бы узнать, что это за регион в действительности.
# - По крупным билетным операторам: "Билеты в руки", "Весь в билетах" - 63%, ряд операторов с 60-61% - "Облачко", "Билеты без проблем" (самый крупный), "Мой билет", "Лови билет!", "Лучшие билеты".

# %% [markdown]
# Итого: какие сегменты пользователей чаще возвращаются в Афишу?
# Выставки и театры имеют хорошую возвращаемость клиентов - 63-64% - доля пользователей с повторными покупками в Афише.
#
# Десктоп в этом контексте чуть лучше мобильных устройств - доля пользователей с повторными покупками в Афише 64%.
#
# Из топа больших регионов с высоким рассматриваемым показателем - Широковская область (65%), Североярская облася (64%).
#
# Операторы держатся в окрестности 62%. Из крупных выделяется "Весь в билетах" - 63%.
#
# Успешными точками входа можно считать театры и выставки, десктоп, Широковскую область и оператора "Весь в билетах".

# %% [markdown]
# ---
#
# #### **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %% [markdown]
# Опираясь на выводы в предыдущем разделе можно заключить, что
# - Гипотеза 1 неверна: пользователи, совершившие первый заказ на спортивное мероприятие имеют долю возвратов в Афишу 56%, тогда как у концертов этот показатель 62%.

# %% [markdown]
# Для проверки второй гипотезы построим диаграмму рассеяния, чтобы найти указанную зависимость.

# %%
segment_region.plot(
    kind='scatter',
    y='is_two_share',
    x='user_count',
    title='Зависимость доли пользователей с 2+ покупками от количества пользователей в регионе',
    xlabel='Количество пользователей в регионе',
    ylabel='Доля пользователей с 2+ покупками',
    figsize=(10, 5),
    alpha=0.5
)
plt.show()

# %% [markdown]
# Диаграмма рассеяния не дает четкого ответа на заданный вопрос. Поэтому попробуем другой подход.

# %%
# возьмем регионы, входящие в 95 перцентиль по количеству пользователей
percentile_users = segment_region['user_count'].quantile(0.95)
big_regions_mean_is_two_share = segment_region[segment_region['user_count'] > percentile_users]['is_two_share'].mean()
small_regions_mean_is_two_share = segment_region[segment_region['user_count'] <= percentile_users]['is_two_share'].mean()
print(f'Средняя доля пользователей с 2+ заказами в больших регионах: {big_regions_mean_is_two_share:.3f}')
print(f'Средняя доля пользователей с 2+ заказами в маленьких регионах: {small_regions_mean_is_two_share:.3f}')
# Out:
# Средняя доля пользователей с 2+ заказами в больших регионах: 0.615
# Средняя доля пользователей с 2+ заказами в маленьких регионах: 0.553

# %% [markdown]
# ~~Так нагляднее: в регионах с большим количеством пользователей Афиши доля пользователей с повторными заказами больше на 0.06, таким образом Гипотеза 2 является верной.~~
#
# Upd:🎁 СНГ: вывод по второй гипотезе переделан ниже

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ сегментов пользователей <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здорово, что функционализируешь выполнение повторяющихся действий! Это облегчает код и уменьшает влияние человеческого фактора.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> С выводами по второй гипотезе не соглашусь. Действительно, важно учитывать размерность групп при сравнении долей! В менее популярных группах 1 дополнительный пользователь имеет больший вес, а потому показатель возвращаемости у таких категорий больше подвержен колебаниям, менее стабилен. Например, если бы у нас в группу с осталными регионами попало только два региона с одним пользователем, в одном вернулось 100%, в другом 0%, среднее 50%, показательно ли это? По скаттерплоту видно, что судя по относительно крупным регионам, в стабильности которых мы более менее уверены, такой зависимости не наблюдается.
#
# Но вообще, чтобы наверняка убедиться в том, что возвращаемость в непопулярных группах ниже, и это не случайное колебание, следует провести статистический тест, оценить значимость различий. Это будет изучаться в дальнейшем на курсе.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * В случае вывода неполного набора сегментов стоит указать, какой процент от выборки они составляют, чтобы было понимание, насколько большая часть данных осталась за пределами нашего обзора.
#
#
# * Обращу внимание, что ввиду различия размерности групп на грфики лучше выводить общую возвращаемость в выборке, а не среднее между возвращаемостями по группам.
#
#
# * В выводах по первым двум частям было бы неплохо также попробовать предположить, почему мы могли получить то или иное распределение по сегментам и определенный уровень возвращаемости, почему показатели оказались именно такими. Это может быть полезно в плане развития стратегий по привлечению новых пользователей.
#
#
# * Напоминаю про моменты, которые уже поясняла в предыдущих комментариях: длина строки кода.
#
# </div>

# %% [markdown]
# ### 🎁 СНГ: согласен с замечанием. Действительно, важно отмести самые маленькие регионы, в которых слишком нестабильные доли.

# %% [markdown]
# Построим диаграмму рассеяния, убирая самые маленькие регионы.

# %%
segment_region.sort_values('user_count', ascending=False).head(20)
# Out:
#                            user_count  is_two_count  is_two_share
# region_name
# Каменевский регион               7086          4422          0.62
# Североярская область             3767          2404          0.64
# Широковская область              1224           790          0.65
# Озернинский край                  675           373          0.55
# Малиновоярский округ              525           294          0.56
# Шанырский регион                  499           335          0.67
# Травяная область                  488           300          0.61
# Светополянский округ              456           299          0.66
# Речиновская область               440           279          0.63
# Яблоневская область               411           244          0.59
# Медовская область                 374           222          0.59
# Верхоречная область               366           212          0.58
# Лугоградская область              358           201          0.56
# ...

# %%
segment_region[segment_region['user_count'] > 400].plot(
    kind='scatter',
    y='is_two_share',
    x='user_count',
    title='Зависимость доли пользователей с 2+ покупками от количества пользователей в регионе',
    xlabel='Количество пользователей в регионе',
    ylabel='Доля пользователей с 2+ покупками',
    figsize=(10, 5),
    alpha=0.5
)
plt.show()

# %% [markdown]
# Действительно, вторая гипотеза не подтверждается: строгой зависимости возвращаемости пользователей от количества пользователей в регионе не наблюдается. Необходимо больше данных для исследования данного вопроса.

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# #### **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
def plot_hist(df, column, groupby, title, xlabel, ylabel, binwidth, kde=False):
    '''
    Функция для визуализации распределения значений с учётом категорий и линией KDE.
    Параметры:
    df - датафрейм с данными для анализа.
    column - str, название столбца, значения которого будут отображаться на графике.
    groupby - str, название столбца, по которому будет производиться группировка данных.
    binwidth - int, ширина корзины для гистограммы.
    title - str, заголовок графика.
    xlabel - str, подпись по оси X.
    ylabel - str, подпись по оси Y.
    kde - наложение графика KDE на гистограмму
    '''

    plt.figure(figsize=(7, 3))

    # Находим диапазон значений
    min_value = int(df[column].min())
    max_value = int(np.ceil(df[column].max()))  # округляем вверх

    # Получаем уникальные значения groupby
    categories = df[groupby].dropna().unique()

    for value in categories:
        subset = df.loc[df[groupby] == value, column].dropna()

        # Проверяем, что есть данные для построения
        if subset.empty:
            print(f"⚠️ Нет данных для {groupby} = {value}")
            continue

        subset.plot(
            kind='hist',
            density=True,
            bins=range(min_value, max_value + 1, binwidth),
            alpha=0.5,
            label=f'{groupby}: {value}',
            legend=True,
            grid=False
        )

        # Опционально: добавить KDE
        if kde:
            subset.plot(
                kind='kde',
                linewidth=2,
                alpha=0.8,
                label=f'KDE {groupby}: {value}'
            )

    # Настройка графика
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xlim(min_value, max_value)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_hist(
    df=df_users,
    column='avg_revenue',
    groupby='is_two',
    binwidth=10,
    title='Распределение средней выручки в зависимости от признака 2+ заказов',
    xlabel='Средняя выручка is_two=True - c 2+ заказами, is_two=False - с 1 заказом',
    ylabel='Плотность',
    kde=True
)

# %% [markdown]
# На графике распределения средней выручки в зависимости от признака 2+ заказов видно отличие двух групп: невернувшиеся пользователи чаще генерируют выручку близкую к 100 рублям, тогда как пользователи с двумя и более заказами приносят чаще выручку в 500 рублей.

# %% [markdown]
# ---
#
# #### **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
IS_2_4 = 'is_2_4'
IS_5_PLUS = 'is_5_plus'
IS_1 = 'is_1'

# Выделим категорияльный признак пользователей - сколько заказов сделал пользователь
def orders_count_cat(row):
    if row['orders_count'] >=2 and row['orders_count'] <=4:
        return IS_2_4
    elif row['orders_count'] >=5:
        return IS_5_PLUS
    else:
        return IS_1

df_users['orders_count_cat'] = df_users.apply(orders_count_cat, axis=1)
df_users.sample(5)
# Out:
#                user_id      first_order_ts       last_order_ts  orders_count  \
# 4770   37d08fa05e317c7 2024-08-23 20:08:53 2024-08-23 20:08:53             1
# 538    0675067ef8b22b1 2024-07-14 21:15:08 2024-10-19 22:09:37             4
# 1012   0c5075db67b4734 2024-10-23 10:27:59 2024-10-23 10:27:59             1
# 7047   520d995e10c222e 2024-09-14 10:55:46 2024-10-31 01:37:42             3
# 19886  e8990d91d8cd358 2024-06-28 12:29:40 2024-10-30 09:10:16             3
#
#        avg_revenue  avg_tickets_count  total_tickets_count  avg_order_delay  \
# 4770    369.820007           3.000000                    3              NaN
# 538     705.097534           2.500000                   10        32.333332
# 1012    164.630005           3.000000                    3              NaN
# 7047    933.820007           2.333333                    7        23.500000
# 19886   917.383362           3.000000                    9        62.000000
#
# ...

# %%
plot_hist(
    df=df_users[df_users['orders_count_cat'].isin([IS_2_4, IS_5_PLUS])],
    column='avg_revenue',
    groupby='orders_count_cat',
    binwidth=10,
    title='Распределение средней выручки в зависимости от количества заказов',
    xlabel='Средняя выручка',
    ylabel='Плотность',
    kde=True
)

# %% [markdown]
# В двух группах пользователей с 2-4 заказами и с 5+ заказами есть существенные отличия в распределении средней выручки: пользователи из первой группы в 2 раза реже приносят выручку в 500 рублей, чем пользователи из второй группы. Пользователи с меньшим количеством заказов склонны приносить в среднем меньшую выручку.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ взаимосвязи средней выручки и числа заказов <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * С этой задачей справились!
#
#
# * Плюсик за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`).
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Выводы сейчас достаточно поверхностные. Стоит выделить конкретные сегменты концентрации - резюмировать информацию с графиков в более понятные лаконичные диапазоны, при этом в том числе обратить внимание на хвосты. А также попробовать подумать, что для нас могут значить данные результаты, почему они могли получиться именно такими, что это говорит о клиентах, об их стабильности? Это может быть полезно в плане развития стратегий по привлечению новых пользователей.
#
# </div>

# %% [markdown]
# ---
#
# #### **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
def tickets_count_cat(row):
    if row['avg_tickets_count'] < 2:
        return '1_2'
    elif row['avg_tickets_count'] < 3:
        return '2_3'
    elif row['avg_tickets_count'] < 5:
        return '3_5'
    elif row['avg_tickets_count'] >= 5:
        return '5+'
    else:
        raise ValueError(f'Странное среднее количество билетов в заказе {row["avg_tickets_count"]}')

df_users['tickets_count_cat'] = df_users.apply(tickets_count_cat, axis=1)
df_users.head(3)
# Out:
#            user_id      first_order_ts       last_order_ts  orders_count  \
# 0  0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03             1
# 1  0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02             2
# 2  000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00             3
#
#    avg_revenue  avg_tickets_count  total_tickets_count  avg_order_delay  \
# 0  1521.939941           4.000000                    4              NaN
# 1   774.010010           3.000000                    6             75.0
# 2   767.213379           2.666667                    8             51.0
#
#   device_type_canonical           region_name  service_name event_type_main  \
# 0                mobile    Каменевский регион  Край билетов           театр
# 1                mobile    Каменевский регион     Мой билет        выставки
# 2                mobile  Североярская область   Лови билет!          другое
#
#    is_five  is_two orders_count_cat tickets_count_cat
# ...

# %%
grouped = df_users.groupby('tickets_count_cat').agg(
    users_count = ('user_id', 'count'),
    is_two_share = ('is_two', 'mean'),
)
grouped
# Out:
#                    users_count  is_two_share
# tickets_count_cat
# 1_2                       2420      0.513223
# 2_3                       9490      0.735511
# 3_5                       9055      0.542794
# 5+                         661      0.187595

# %% [markdown]
# В группе пользователей, которые покупают 2-3 билета в среднем, больше всего доля пользователей, совершивших повторные заказы - 74%. Самая низкая доля у категории, в которой пользователи покупают 5 и более билетов.
#
# Такая картина вероятно связана с типовыми покупателями билетов на Афише: обычные пользователи, которые покупают 2-3 билета в среднем (а мы помним, что медианное значение количества билетов в заказе как раз равно 2-м и эта группа пользователей самая большая), это обычные пользователи, которые время от времени ходят на культурные мероприятия. Пользователи с большим количеством билетов в заказах скорее всего делают покупки разово на группу людей (одноклассников/одногруппников или друзей), поэтому доля вернувшихся пользователей в этой категории относительно мала и составляет 19%, но и пользователей в этой группе на порядок меньше, чем в остальных.
#
# Другие группы 1-2 билета и 3-5 билетов имеют примерно одинаковую долю вернувшихся пользователей около 52%.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ взаимосвязи количества билетов в заказе и возвращаемости <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здесь тоже все окей, справились! Здорово, что в выводах предполагаешь, что за сегменты у нас сформировались.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
# * Для сегментации данных есть довольно удобный метод [сut](https://pandas.pydata.org/docs/reference/api/pandas.cut.html). Можно задать границы интервалов и последовательный список наименований сегментов и они автоматически сформируются. Необходимо только правильно настроить параметр `right`, который по умолчанию имеет значение `True`, и параметр `include_lowest`, по умолчанию имеющий значение `False`, чтобы у нас включались и исключались нужные нам границы интервала.
#
#
# * Для удобства анализа было бы неплохо визуализировать результаты.
#
#
# </div>

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# #### **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
df_users['first_order_day_of_week'] = df_users['first_order_ts'].dt.day_name()
df_users['first_order_day_of_week_num'] = df_users['first_order_ts'].dt.day_of_week
grouped = df_users.groupby(['first_order_day_of_week', 'first_order_day_of_week_num']).agg(
    users_count = ('user_id', 'count'),
    is_two_share = ('is_two', 'mean'),
)
grouped
# Out:
#                                                      users_count  is_two_share
# first_order_day_of_week first_order_day_of_week_num
# Friday                  4                                   3260      0.598160
# Monday                  0                                   2929      0.630249
# Saturday                5                                   3324      0.627858
# Sunday                  6                                   2777      0.600288
# Thursday                3                                   3114      0.594412
# Tuesday                 1                                   3165      0.618957
# Wednesday               2                                   3057      0.621851

# %%
plot = grouped.sort_values('first_order_day_of_week_num').plot(
    kind='bar',
    title='Зависимость количества пользователей\nи доли пользователей с 2+ покупками от дня недели',
    xlabel='День недели',
    rot=45,
    legend=False,
    subplots=True,
    sharex=True,
    sharey=False,
    figsize=(10, 10),
)
plot[0].grid(which='both')
plot[1].grid(which='both')


users_count_mean = grouped['users_count'].mean()
plot[0].text(0.5, 0.9, 'Ср. знач.: {:.0f}'.format(users_count_mean),
             horizontalalignment='center',
             verticalalignment='top',
             color='red',
             transform=plot[0].transAxes)
plot[0].axhline(users_count_mean, color='red', linestyle='--')

is_two_share_mean = grouped['is_two_share'].mean()
plot[1].text(0.5, 0.9, 'Ср. знач.: {:.2f}'.format(is_two_share_mean),
             horizontalalignment='center',
             verticalalignment='top',
             color='blue',
             transform=plot[1].transAxes,
)
plot[1].axhline(is_two_share_mean, color='blue', linestyle='--')


plot[0].set_ylabel('Количество пользователей')
plot[1].set_ylabel('Доля пользователей с 2+ покупками')
plot[0].set_title(None)
plot[1].set_title(None)
# plot[0].set_ylim(2500, 3500)
# plot[1].set_ylim(0.5, 0.7)
plt.show()

# %% [markdown]
# По диаграммам выделяется суббота - в этот день происходит наибольшее количество первых покупок билетов на Афише. Это логично, люди начинают выбирать билеты, когда у них появляется свободное время - в выходные. Выделяются также вторник и пятница - количество пользователей в эти дни больше среднего. Пятница - логично, люди ищут билеты на выходные.
#
# Также интересен факт, что пользователи, совершившие первый заказ в субботу имеют наибольшую вероятность к повторной покупке билетов на Афише - доля пользователей с повторной покупкой - 0.64, тогда как в четверг наименьшая - 0.6.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ возвращаемости по дням недели  <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здесь все корректно. Различия по дням недели все же наблюдаются, хотя и не очень заметные. Чтобы судить более однозначно, было бы неплохо сопроводить сравнение оценкой статистической значимости. Это будет изучаться далее на курсе.
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b> При отображении долей и количеств обычно оси фиксируют на 0, чтобы визуально не катастрофизировать небольшие колебания.
#
# </div>

# %% [markdown]
# ---
#
# #### **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
grouped = df_users[df_users['orders_count_cat'].isin([IS_2_4, IS_5_PLUS])].groupby('orders_count_cat').agg(
    avg_order_delay_mean=('avg_order_delay', 'mean'),
    users_count=('user_id', 'count'),
)
grouped
# Out:
#                   avg_order_delay_mean  users_count
# orders_count_cat
# is_2_4                       21.324766         7148
# is_5_plus                     9.922736         6113

# %% [markdown]
# По имеющимся данным можно сделать вывод, что пользователи, сделавшие 2-4 заказа в Афише делают, оформляют билеты раз в 3 недели. Тогда как пользователи с бОльшим количеством заказов делают из чаще - в среднем раз в 10 дней. Однако, последнее значение может быть подвержено значительному смещению из-за пользователей, осуществляющих очень большое количество заказов. Давайте это проверим, для чего выделим больше групп по числу заказов в колонке `orders_count_cat_detailed`:

# %%
df_users
# Out:
#                user_id      first_order_ts       last_order_ts  orders_count  \
# 0      0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03             1
# 1      0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02             2
# 2      000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00             3
# 3      00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48             1
# 4      000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04             2
# ...                ...                 ...                 ...           ...
# 21843  fff13b79bd47d7c 2024-07-16 22:17:10 2024-10-31 18:31:52             9
# 21844  fff32fc9ad0f9f6 2024-08-15 14:36:28 2024-10-28 23:40:38             2
# 21845  fffcd3dde79eb2c 2024-06-20 19:57:25 2024-10-30 13:37:43            33
# 21846  fffeeb3c120cf0b 2024-09-24 10:07:42 2024-09-24 10:07:42             1
# 21847  ffff00725179321 2024-09-25 15:12:40 2024-09-25 15:12:40             1
#
# ...

# %%
IS_2_4 = 'is_a_2_4'
IS_5_9 = 'is_b_5_9'
IS_10_19 = 'is_c_10_19'
IS_20_49 = 'is_d_20_49'
IS_50_PLUS = 'is_e_50_plus'

# Выделим категорияльный признак пользователей - сколько заказов сделал пользователь
def orders_count_cat_detailed(row):
    if row['orders_count'] == 1:
        return IS_1
    elif row['orders_count'] <= 4:
        return IS_2_4
    elif row['orders_count'] <= 9:
        return IS_5_9
    elif row['orders_count'] <= 19:
        return IS_10_19
    elif row['orders_count'] <= 49:
        return IS_20_49
    else:
        return IS_50_PLUS

df_users['orders_count_cat_detailed'] = df_users.apply(orders_count_cat_detailed, axis=1)

df_users.groupby('orders_count_cat_detailed').agg(
    avg_order_delay_mean=('avg_order_delay', 'mean'),
    users_count=('user_id', 'count'),
)
# Out:
#                            avg_order_delay_mean  users_count
# orders_count_cat_detailed
# is_1                                  42.370369         8365
# is_a_2_4                              21.324766         7148
# is_b_5_9                              13.675994         3049
# is_c_10_19                             8.549663         1554
# is_d_20_49                             4.683682         1011
# is_e_50_plus                           1.880164          499

# %% [markdown]
# Это интересно, в группе с 1 заказом существуют пользователи, у которых ненулевое значение времени между заказами. По определению таких пользователей не должно быть.
# Исследуем эту особенность.

# %%
# Выведем пользователей с 1 заказом и ненулевым временем между заказами:
strange_users = df_users[(df_users['orders_count_cat_detailed'] == IS_1) & ~df_users['avg_order_delay'].isna()].sort_values('avg_order_delay', ascending=False)
print('Количество пользователей с 1 заказом и ненулевым временем между заказами:', strange_users.shape[0])
strange_users
# Out:
# Количество пользователей с 1 заказом и ненулевым временем между заказами: 27
#                user_id      first_order_ts       last_order_ts  orders_count  \
# 18209  d4981202db1011c 2024-10-21 12:06:06 2024-10-21 12:06:06             1
# 4985   3a12f997c1c3c9f 2024-10-20 01:48:29 2024-10-20 01:48:29             1
# 308    03c3b562c152c1f 2024-10-22 17:37:55 2024-10-22 17:37:55             1
# 11289  845fc48fc11e21d 2024-09-27 12:33:58 2024-09-27 12:33:58             1
# 21381  faa6f6c2be4f1b5 2024-09-27 22:41:46 2024-09-27 22:41:46             1
# 5261   3d58a2e893f46a0 2024-09-13 15:15:08 2024-09-13 15:15:08             1
# 20111  eb7eada722c5790 2024-09-03 10:02:54 2024-09-03 10:02:54             1
# 14201  a6d5e23b58ae655 2024-10-11 18:11:08 2024-10-11 18:11:08             1
# 19019  de26b0ffb9c0553 2024-09-02 20:52:08 2024-09-02 20:52:08             1
# 17316  ca197ee09285dab 2024-09-09 18:20:01 2024-09-09 18:20:01             1
# ...

# %%
# проверим, что данная ошибка не была внесена промежуточными вычислениями над датасетом df_users и присутствует в исходном датасете
df1 = df.groupby(['user_id']).agg(
    orders_count=('order_id', 'count'),
    delay=('days_since_prev', 'mean')
)
strange_users = df1[((df1['orders_count'] < 2) & ~df1['delay'].isna()) | ((df1['delay'].isna()) & (df1['orders_count']) > 1)]
print('Количество пользователей с 1 заказом и ненулевым временем между заказами (по исходному датасету):', strange_users.shape[0])
display(strange_users)
# Out:
# Количество пользователей с 1 заказом и ненулевым временем между заказами (по исходному датасету): 27
#                  orders_count  delay
# user_id
# 03c3b562c152c1f             1  123.0
# 062f4b62768fab7             1    0.0
# 1281e0b114c6980             1    0.0
# 19e9215419c54a7             1    0.0
# 2b257f6a8260468             1    1.0
# 3a12f997c1c3c9f             1  124.0
# 3d58a2e893f46a0             1   99.0
# 4d91509b410294e             1    5.0
# 59ad4dee7cd2d10             1    0.0
# 5ffacf774dee06c             1    0.0
# 69d8c607f502e54             1   36.0
# 845fc48fc11e21d             1  118.0
# 88d3b417430c3de             1   49.0
# 9d4533ac70b41d5             1    1.0
# 9d62da7b58a720b             1   35.0
# 9f7950ada5a45b3             1   21.0
# a6d5e23b58ae655             1   62.0
# bc3c185bc9093e8             1    0.0
# c6a6665fa0217b4             1    0.0
# ca197ee09285dab             1   50.0
# ca8d42309c14875             1   11.0
# ...

# %% [markdown]
# Проблема характерна и для исходного датасета. Взглянем на заказы данных пользователей в исходном датасете:

# %%
df_strange = df[df['user_id'].isin(strange_users.reset_index()['user_id'])].sort_values(['user_id', 'order_ts'])
df_strange[df_strange['user_id'] == '03c3b562c152c1f']
# Out:
#               user_id device_type_canonical  order_id   order_dt  \
# 6621  03c3b562c152c1f                mobile   2221227 2024-10-22
#
#                 order_ts currency_code      revenue  tickets_count  \
# 6621 2024-10-22 17:37:55           rub  1503.569946              3
#
#       days_since_prev  event_id                            event_name  \
# 6621            123.0    570458  94679ef8-4903-4c48-9b7e-068e01d7c50f
#
#      event_type_main service_name          region_name     city_name  \
# 6621        концерты       Яблоко  Речиновская область  Дальнесветск
#
#       revenue_rub
# 6621  1503.569946

# %%
# df_strange = df[df['user_id'].isin(strange_users.reset_index()['user_id'])].sort_values(['user_id', 'order_ts'])
# print('Количество строк в исходном датасете с заказами странных пользователей:', df_strange.shape[0])
# df_strange

query = """
SELECT
  user_id,
  device_type_canonical,
  order_id,
  created_dt_msk as order_dt,
  created_ts_msk as order_ts,
  currency_code,
  revenue,
  tickets_count,
  extract(day from created_dt_msk - LAG(created_dt_msk) over (partition by user_id order by created_dt_msk)) as days_since_prev,
  event_id,
  event_name_code as event_name,
  event_type_main,
  service_name,
  region_name,
  city_name
from
  afisha.purchases p
left join
  afisha.events e
using
  (event_id)
left join
  afisha.city c
using
  (city_id)
left join
  afisha.regions r
using
  (region_id)
where
  device_type_canonical in ('mobile', 'desktop')
  and event_type_main != 'фильм'
  and user_id = '03c3b562c152c1f'
order by
    user_id, order_ts
;
"""
df_strange_users_from_sql = pd.read_sql_query(query, con=engine)

# %%
print(f'Данные пользователя  в датасете, выгруженном по SQL:')
display(df_strange_users_from_sql)
print(f'Данные пользователя в нашем исходном датасете:')
df[df['user_id'] == '03c3b562c152c1f']
# Out:
# Данные пользователя  в датасете, выгруженном по SQL:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  03c3b562c152c1f                mobile    710327 2024-06-21
# 1  03c3b562c152c1f                mobile    710385 2024-06-21
# 2  03c3b562c152c1f                mobile    710356 2024-06-21
# 3  03c3b562c152c1f                mobile   2221227 2024-10-22
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-06-21 22:51:36           rub  2722.81              4              NaN
# 1 2024-06-21 22:57:26           rub  2722.81              4              0.0
# 2 2024-06-21 22:58:10           rub  3403.51              5              0.0
# 3 2024-10-22 17:37:55           rub  1503.57              3            123.0
#
#    event_id                            event_name event_type_main  \
# 0    517714  9cc55c15-4375-4129-9979-3129688ba1b4        концерты
# 1    517714  9cc55c15-4375-4129-9979-3129688ba1b4        концерты
# ...

# %%
print('Количество строк оригинального датасета, в которых участвуют странные пользователи с 1 заказом и ненулевым количеством дней между заказами:')
len(df_original[df_original['user_id'].isin(strange_users.reset_index()['user_id'])])
# Out:
# Количество строк оригинального датасета, в которых участвуют странные пользователи с 1 заказом и ненулевым количеством дней между заказами:
# 67

# %% [markdown]
# В исходном датасете из SQL есть 4 заказа пользователя, хотя в нашем датасете, построенном по этому SQL, только 1 заказ. Это означает, что предыдущие строки заказов были отфильтрованы в ходе исследования, например, при очистке выбросов по `revenue`.
#
# Дальнейший анализ это подтвердил: 99-й процентиль по revenue_rub: 2628 рублей. Соответственно заказы с revenue > чем 99 процентиль были удалены из датасета.
#
# Итого: таких пользователей в датасете с профилями пользователей не много - всего 27. Можно пренебречь ими в данном разделе, так как их доля заказов в оригинальном датасете ничтожно мала - 67 заказов.

# %% [markdown]
# Вернемся к анализу влияния времени между заказами на возвращаемость пользователей в Афишу, исключим странных пользователей, описанных выше.

# %%
df_users[df_users['orders_count_cat_detailed'].isin([IS_2_4, IS_5_9, IS_10_19, IS_20_49, IS_50_PLUS])].groupby('orders_count_cat_detailed').agg(
    avg_order_delay_mean=('avg_order_delay', 'mean'),
    users_count=('user_id', 'count'),
)
# Out:
#                            avg_order_delay_mean  users_count
# orders_count_cat_detailed
# is_a_2_4                              21.324766         7148
# is_b_5_9                              13.675994         3049
# is_c_10_19                             8.549663         1554
# is_d_20_49                             4.683682         1011
# is_e_50_plus                           1.880164          499

# %% [markdown]
# Как видно из таблицы, чем больше заказов сделал пользователь, тем меньше среднее время между заказами. При этом и количество пользователей уменьшается обратно пропорционально количеству заказов.
#
# Вывод: культура вызывает привыкание, чем больше пользователь оформляет заказов на мероприятия, тем чаще ему хочется ходить на них.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ возвращаемости по количеству дней между заказами <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> По расчетам все верно!
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
#
# * Проблемы с нулевым количеством дней не возникло бы, если на этапе предобработки после борьбы с выбросами мы пересчитали количество дней между заказами.
#
#
# * Важно иметь в виду, что среднее значение как раз довольно сильно зависит от характера распределения, если есть какие-то сильные выбросы, они могут утянуть среднее значение вверх, хотя основаня масса значений будет гораздо ниже. Поэтому здесь удобнее было бы построить гистограммы (как мы это делали при сравнении выручки), чтобы можно было полноценно сравнить их характер распределения.
#
#
# * Вывод довольно банален. Логично, что на ограниченном промежутке времени у клиента с большим количеством заказов интервалы будут меньше. Поэтому здесь стоит делать обратный ход - подумать, как по интервалу времени после очередного заказа можно определять, есть ли шанс, что клиент еще вернется самостоятельно, или пора подключать стратегии для вовлечения в новый заказ.
#
#
# * Напоминаю про моменты, которые уже поясняла в предыдущих комментариях: длина строки кода, вывод неограниченного числа строк.
#
# </div>

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# #### **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
corr_matrix = df_users[[
    'orders_count',
    # 'first_order_ts',
    # 'last_order_ts',
    'avg_revenue',
    'avg_tickets_count',
    # 'total_tickets_count',
    'avg_order_delay',
    'device_type_canonical',
    'region_name',
    'service_name',
    'event_type_main',
    'first_order_day_of_week',
    'first_order_day_of_week_num',
    # 🎁 СНГ: добавил количество заказов в интервальные признаки
]].phik_matrix(interval_cols=['orders_count', 'avg_revenue', 'avg_tickets_count', 'avg_order_delay'])

data_heatmap = corr_matrix.loc[corr_matrix.index != 'orders_count'][['orders_count']].sort_values(by='orders_count', ascending=False)

sns.heatmap(data_heatmap, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Корреляции количества заказов с признаками профиля пользователя')
plt.xlabel('Корреляция с количеством заказов')
plt.ylabel('Признак профиля пользователя')
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/ngsmirnov/nikki/projects/practicum/sprint_8_afisha_project/.venv/lib/python3.14/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 297, in main
#     raise ValueError(
#     ...<4 lines>...
#     )
# ValueError: Cannot register "REGISTER","rtype":"folder","base64_name" for automatic cleanup: unknown resource type ("L3Zhci9mb2xkZXJzL3F5L3ZyaGdrNDY1M3p4M3BwODFwYjVobjg1MDAwMDBnbi9UL2pvYmxpYl9tZW1tYXBwaW5nX2ZvbGRlcl82MjI1N19iMzUzYmU1YTBiMzI0YjVmYTg1MGUwYjhiOWE4YjM0ZV9lNmM3MjFhOGQ4ZGI0NzIwODYxZTkyZmJlNDkyODQ0Mw=="}). Resource type should be one of the following: ['noop', 'folder', 'file', 'semlock']
# Traceback (most recent call last):
#   File "/Users/ngsmirnov/nikki/projects/practicum/sprint_8_afisha_project/.venv/lib/python3.14/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 297, in main
#     raise ValueError(
#     ...<4 lines>...
#     )
# ...

# %% [markdown]
# Тепловая карта, построенная по корреляционной phik-матрице показывет, что значение количества заказов имеет умеренную связь со средним временем между заказами, как мы видели в предыдущей части анализа. ~~Интересно, что билетный оператор (service_name) также имеет умеренную связь с количеством заказов.~~
#
# Также наблюдается умеренная связь количества заказов со средним количеством билетов в заказе и средней выручкой с одного заказа.

# %% [markdown]
# Чем меньше среднее время между заказами, тем больше заказов делает пользователь. Логично. Можно стимулировать чаше пользователей обращаться в Афишу через нотификации, чтобы было больше заказов.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ корреляции <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Корреляция интерпретируется верно! Phik всегда положительный и не дает информации о направленности, поэтому мы можем судить лишь о силе взаимосвязи. Говорить, что чем больше что-то одно, тем больше/меньше что-то другое, не корректно. Об этом мы можем лишь предполагать с точки зрения здравого смысла или судить по результатам дополнительного анализа.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> `total_orders` тоже ведь количественный признак в первой части, поэтому его необходимо включить в `interval_cols`. Иначе сейчас каждое значение рассматривается индивидуально, и из-за редких билетных операторов, с которомы связь получается однозначной, их корреляция вылетает в топ, но это ложный результат.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
#
# * Обрати внимание, что Phik бинаризует количественные признаки из расчета имеющегося диапазона, поэтому имеет смысл создать сегменты по количеству заказов самостоятельно, чтобы они были более сбалансированы по составу, и уже с ними проверять корреляцию.
#
#
# *  В выводах было бы неплохо провести параллель с нашими предыдущими шагами анализа. Прокомментировать, почему высокая корреляция получается с одними признаками и низкая с другими. Что по итогу важно для манипулирования возвращаемостью клиентов, а что нет?
#
#
# * Напоминаю про моменты, которые уже поясняла в предыдущих комментариях: длина строки кода.
#
# </div>

# %% [markdown]
# ### 🎁 СНГ: согласен, действительно, отсутствие orders_count в интервальных признаках приводит к искажению результатов. Поправил вывод выше.

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# #### Вывод по проекту
#
# **Информация о данных и их предобработка:**
#
# В исследовании использовался датасет заказов платформы Яндекс Афиша за период с 1 июня по 31 октября 2024 года. Исходный датасет содержал 290 тыс. строк и 15 колонок. В ходе предобработки данных были выполнены следующие действия:
# - Выручка в казахстанских тенге (5 тыс. строк, 2%) приведена к российским рублям по курсу на дату заказа. Создан новый столбец `revenue_rub`.
# - Удалены выбросы по выручке (99-й перцентиль - 2628 рублей), что составило около 3 тыс. строк (1%).
# - Удалены дубликаты по `user_id` и `order_ts` - около 170 строк.
# - Скорректированы типы данных колонок, что сэкономило 33% памяти (22 МБ вместо 33 МБ).
#
# После очистки датасет содержит 287 тыс. заказов от 21.8 тыс. уникальных пользователей.
#
# **Основные результаты анализа:**
#
# **1. Распределение пользователей:**
# - 38% пользователей совершили только 1 заказ
# - 62% пользователей вернулись и сделали 2+ заказа
# - 29% пользователей совершили 5+ заказов
# - Средняя выручка с одного заказа - 543 рубля, медиана - 351 рубль
# - Среднее количество билетов в заказе - 2.7, медиана - 3
# - Среднее время между покупками - 16 дней
# - 44% пользователей покупают билеты на концерты, другое - 25%, театр - 20%
# - 82% пользователей покупают с мобильных устройств
# - Каменевский регион и Североярская область - самые активные регионы по пользователям (7к/33% и 4к/18% соответственно)
# - 23% пользователей заходят через оператора "Билеты без проблем" (еще 4 оператора делят доли по 10-14%)
#
# **2. Выявлена когорта суперактивных пользователей:**
# - 1% пользователей (220 человек), которые совершили 49% всех заказов в датасете
# - Максимум - 10160 заказов от одного user_id
# - Эти пользователи не удалялись из анализа, так как представляют важную когорту (возможно корпоративные клиенты или реселлеры)
#
# **3. Признаки первого заказа, связанные с возвратом пользователей:**
#
# *Тип мероприятия:*
# - Театр - 64% возвратов (лидер)
# - Выставки - 64%, но тут мало пользователей
# - Концерты - 62%
# - Стендап - 61%
# - Спорт - 56% (худший показатель)
#
# *Тип устройства:*
# - Десктоп - 64% возвратов
# - Мобильные - 62%
# - Различие небольшое, но стабильное
#
# *Регион:*
# - Широковская область - 65% возвратов (лидер, но тут мало пользователей - примерно 1200/5%)
# - Североярская область (предположительно СПб) - 64%
# - Каменевский регион (предположительно Москва) - 63%
# - В крупных регионах доля возвратов выше на 6% по сравнению с мелкими
#
# *Билетный оператор:*
# - "Весь в билетах", "Билеты в руки" - 63%
# - Остальные крупные операторы - около 61-62%
#
# **4. Связь выручки и количества билетов с повторными покупками:**
#
# *Средняя выручка:*
# - Пользователи с 1 заказом чаще приносят выручку около 100 рублей
# - Пользователи с 2+ заказами чаще приносят выручку около 500 рублей
# - Пользователи с 5+ заказами имеют в 2 раза более высокую среднюю выручку по сравнению с пользователями с 2-4 заказами
#
# *Среднее количество билетов в заказе:*
# - 2-3 билета - 74% возвратов (оптимальная группа)
# - 1-2 билета - 52%
# - 3-5 билетов - 52%
# - 5+ билетов - 19% (покупки на группу, разовые клиенты)
#
# **5. Временные характеристики:**
#
# *День недели первой покупки:*
# - Суббота - лучший день (64% возвратов, наибольшее количество новых пользователей)
# - Четверг - худший день (60% возвратов)
# - Различие составляет 4%, что может быть важно при планировании рекламных кампаний
#
# *Интервалы между покупками:*
# - Пользователи с 2-4 заказами - раз в 3 недели
# - Пользователи с 5+ заказами - раз в 10 дней
# - Чем больше заказов, тем короче интервал между ними (культура вызывает привыкание)
#
# **6. Корреляционный анализ:**
#
# Наиболее связанные с количеством заказов признаки:
# - Среднее время между заказами (умеренная связь)
# - Билетный оператор (умеренная связь)
# - Остальные признаки имеют слабую связь
#
# **7. Проверка гипотез:**
# - Гипотеза 1 о возвратных мероприятиях (спорт > концерты) - **опровергнута**: спорт 56% vs концерты 62%
# - Гипотеза 2 о регионах (в крупных регионах выше возвраты) - **подтверждена**: 62% vs 56%
#
# **Рекомендации для маркетинговой команды:**
#
# **1. Успешные "точки входа" - усилить маркетинг:**
# - Театральные мероприятия и выставки (64% возвратов)
# - Десктопная версия сайта (проще оформление, больше лояльность)
# - Широковская и Североярская области
# - Оператор "Весь в билетах"
# - Субботние рекламные кампании для привлечения новых пользователей
#
# **2. Проблемные сегменты - требуют дополнительных усилий:**
# - Спортивные мероприятия (56% возвратов) - рассмотреть специальные предложения для болельщиков
# - Мелкие регионы (56% возвратов) - персонализированные акции, активация региональных операторов
# - Четверг как день первой покупки - возможно, стоит усилить предложения в этот день
#
# **3. Сегментация клиентов:**
# - **VIP-клиенты** (1%, 152+ заказа на пользователя) - отдельная стратегия работы с такими клиентами, корпоративные пакеты, персональный менеджер, скидки, снятие ограничений на количество билетов в заказе.
# - **Лояльные** (29%, 5+ заказов) - программа лояльности, бонусы за частоту покупок
# - **Перспективные** (33%, 2-4 заказа) - реактивационные кампании, напоминания о мероприятиях раз в 3 недели
# - **Разовые** (38%, 1 заказ) - триггерные email-кампании через 2-3 недели после первой покупки
#
# **4. Оптимизация предложений:**
# - Стимулировать покупку 2-3 билетов (74% возвратов пользователей) через парные/семейные пакеты
# - Пользователи с выручкой 500+ рублей более лояльны - предлагать им premium-мероприятия
# - Для пользователей с высокой частотой заказов (раз в 10 дней) - подписочные модели
#
# **5. Таргетинг рекламы:**
# - Фокус на театры и выставки в крупных городах
# - Усиленный фокус на десктопную аудиторию
# - Запуск рекламных кампаний в пятницу-субботу для максимального охвата
# - Партнерство с оператором "Весь в билетах" для совместных акций

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Итоговые выводы <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С задачей справились! Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Ключевые моменты здесь суховаты - больше пересказ статистики, чем пояснение обнаруженных инсайтов. В выводах мы складываем все полученные инсайты в единую картину, а цифры должны быть лишь подкреплением наших суждений.
#
# </div>

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**
#
# Проект размещен на [GitHub.com/nikolai/practicum-afisha](https://github.com/nikolai/practicum-afisha)

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Публикация в Git <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> По ссылке есть все необходимые данные, в целом все окей.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> Не забудь обновить файл с проектом, после того, как скроешь ключи из текста задания.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
# * В `requirements.txt` не принято дозволять как более новые, так и более старые версии библиотек. В какой-то момент это может привести к конфликту версий. Поэтому необходимо указывать ровно то, что было использовано.
#
#
# * Можно заполнить `readme` полезной информацией о проекте, зафиксировать цели, указать ключевые моменты и полученные выводы.
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; border-radius: 10px;  padding: 40px">
# <h3>Общий вывод по проекту <a class="tocSkip"></h3>
#
# Николай, спасибо за твой проект! У тебя хорошая работа! В тебе виден будущий профессионал своего дела :) Однако есть еще моменты, которые требуют твоего внимания. Кратко пройдусь по впечатлениям.
#
# **Полнота:** все требуемые задачи были выполнены!
#
# **Корректность:**
#
# * <span style="color:Red;">Необходимо засекретить подключение к БД, чтобы не скомпромитировать явки и пароли. Не забываем обновить файл в Git.</span>
# * <span style="color:Red;">Необходимо пересмотреть решение в отношении обработки выбросов.</span>
# * <span style="color:Red;">Необходимо пересмотреть выводы в отношении гипотезы по сегментам, сформированным первыми заказами.</span>
# * <span style="color:Red;">Необходимо пересмотреть оценку корреляции.</span>
#
# **Аналитическая проницательность:** ты верно подмечаешь все ключевые нюансы данных, даешь дельные рекомендации! Местами можно чуть углубить суждения, фиксировать не только то, что наблюдаем, но и предполагать, почему получилось именно так.
#
# **Эффективность кода:** по этому критерию в целом тоже все окей! В некоторых местах можно использовать чуть более удобные и компактные методы.
#
# **Оформление:** им тоже важно не пренебрегать! Оформление тесно связано с удобством восприятия предоставляемой информации и созданием впечатления о работе. Твоя работа в целом довольно аккуратная - выделены разделы, грамотно оформлены графики, ведется последовательный сторителлинг с обоснованиями, но еще есть некоторый потенциал для улучшений (смотри по ходу работы).
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
# <img src="https://99px.ru/sstorage/86/2015/12/image_86271215043043632690.gif" />
